# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections
import pymongo

# %%
import os
datadir = "C:\Users\sampa\Desktop\Other\Udacity\Lesson 4"
datafile = "bangalore.osm"
cal_data = os.path.join(datadir, datafile)

# %%
def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
cal_tags = count_tags(cal_data)
pprint.pprint(cal_tags)
# Out:
# {'bounds': 1,
#  'member': 6000,
#  'nd': 3683187,
#  'node': 2986688,
#  'osm': 1,
#  'relation': 946,
#  'tag': 816117,
#  'way': 662747}

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

cal_keys = process_map(cal_data)
pprint.pprint(cal_keys)
# Out:
# {'lower': 777263, 'lower_colon': 37700, 'other': 1149, 'problemchars': 5}

# %%
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = process_map(cal_data)
len(users)
# Out:
# 1914

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway", 
                         "Place", "Road", "Square", "Street", "Trail"]

mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'street' :"Street",
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square"}

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %%
cal_street_types = audit(cal_data)

# %%
pprint.pprint(dict(cal_street_types))
# Out:
# {'02': set(['756/77/1 marathahalli -sarajpur outer ring road bellandur,banglore 02']),
#  '03': set(['56,srinivas reddy building bellandur banglore 03',
#             'mantri commercio tower B 5th floor outer ring road marathahalli banglore 03']),
#  '048': set(['Whitefield Main Rd, Whitefield, Inner Valley, Whitefield, Bengaluru, Karnataka 560 048']),
#  '1': set(['2nd Main Road, Electronic City Phase 1',
#            '3rd Main,KEB Layout, BTM Layout  1',
#            "4th floor, 27th Main, Above Gold's Gym, Near CPWD Complex, Sector 1",
#            'Borewell Road,Phase 1',
#            'Chikka Madivala BTM Layout 1',
#            'EPIP Area, Road No. 1',
#            'Electronic City Phase 1',
#            'Shikaripalya Road, Electronic City - 1']),
#  '1,': set(['18th Main Rd, Cashier Layout, 1st Stage, BTM Layout 1,',
#             '1st Cross Rd, Aicobo Nagar, 1st Stage, BTM Layout 1,',
#             'Chocolate Factory Rd, Cashier Layout, 1st Stage, BTM Layout 1,']),
#  '100': set(['100']),
#  '18th': set(['18th']),
#  '2': set(['22nd Cross, HSR Layout, Sector 2',
#            '4th Floor, HNR Tower 24th Main 2nd Sector, HSR Layout Sector 2',
#            'Hsr Layout Sector 2',
#            'Near Parangi Palya Bus Stop  HNR Tower 24th Main 2nd Sector, HSR Layout Sector 2']),
#  '2,': set(['3rd Cross Road, Defence Colony, Indiranagar Stage 2,']),
#  '2585': set(['12FHosur Road, Bommanahalli, Bangalore Telephone: +91 80 4191 2585']),
#  '35': set(['Asmath Arcade, Behind-Canara Bank, Varthur, SH 35',
#             'State Highway 35']),
#  '4': set(['National Highway 4']),
#  u'4,\xa0HSR\xa0Layout': set([u'17th Cross, 19th Main Road, Sector 4,\xa0HSR\xa0Layout']),
#  '44': set(['#37/20, 2nd main, Rajajinagar industrial town, Bangalore 44']),
#  '560003': set(['16th Cross, Vyalikaval, Malleswaram, Near Sankey Tank And Chowdiah Memorial Hall, Bhadrappa Layout, Vyalikaval, Kodandarampura, Malleshwaram, Bengaluru, Karnataka 560003',
#                 '18th Cross Rd, Malleshwaram, Bengaluru, Karnataka 560003']),
#  '560032': set([',Unique Center, 1st Floor, Above Unilet Electronics, 80 Feet Rd,, , RT Nagar, Bhadrappa Layout, P&T Colony, RT Nagar, Bengaluru, Karnataka 560032']),
#  u'560038\xa0(': set([u'6th Main Road, Indiranagar, Bangalore - 560038\xa0(']),
#  '560040"': set([', Balu Arcade, 8th Main Road,19th Cross, CHBS Layout, Vijayanagar, CHBS Layout, MC Layout, Vijayanagar, Bengaluru, Karnataka 560040"']),
#  '560053': set(['I Cross, As Char Street, Santhusapet, Chickpet, Bengaluru, Karnataka 560053']),
#  u'560058': set(['11th Main Rd, 3rd Stage, Peenya, Bengaluru, Karnataka 560058',
#                  u'426, Phase IV, Peenya Industrial Area, Peenya, Bengaluru, Karnataka \u2013 560058',
#                  u'487/A, 4th Phase, Peenya Industrial Area, 13th Cross Road, Rotary Udyog Road. Near Post Office, Peenya, Bengaluru, Karnataka \u2013 560058',
#                  u'A-14, 1st Main, 2nd Stage, Peenya Industrial Estate, Peenya, Bengaluru, Karnataka \u2013 560058',
#                  u'Peenya Industrial Area, Peenya, Bengaluru, Karnataka \u2013 560058',
#                  'Sri Muneshwara Estate, Opposite Peenya Police Station, Peenya, Peenya, Kalika Nagar, Ragavendra Nagar, Bengaluru, Karnataka 560058']),
#  u'560058.': set([u'#704 Padmanabhaiah Building Near KEB Office, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'10th Cross Road, Ganapathy Nagar, Phase 3, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'16-A, Peenya Industrial Area, Phase-1, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'2nd Main Road, Nalagadderanahalli, Peenya Industrial Area, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'9th Main Road, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'A6, Imn Road, Peenya Industrial Area, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'No 10, Dodanna Industrial Estate, Peenya Industrial Area, 2nd Stage, Peenya, Bengaluru, Karnataka \u2013 560058.',
#                   u'No: V-48, 5th Main, 2nd Stage, Peenya Industrial Area, Peenya, Bengaluru, Karnataka \u2013 560058.']),
#  '560066': set(['Borewell Rd, Nallurhalli, Whitefield, Bengaluru, Karnataka 560066',
#                 'Borewell Rd, Palm Meadows, Dodsworth Layout, Whitefield, Bengaluru, Karnataka 560066',
#                 'Borewell Rd, Palm Meadows, Nallurhalli, Whitefield, Bengaluru, Karnataka 560066',
#                 'Borewell Road, Whitefield, Palm Meadows, Whitefield, Bengaluru, Karnataka 560066',
#                 'KIADB Export Promotion Industrial Area, Whitefield, Bengaluru, Karnataka 560066',
#                 'Opposite to FourPoints by Sheraton,, Whitefield Main Road, Ambedkar Nagar, Whitefield, Happy Valley, Whitefield, Bengaluru, Karnataka 560066',
#                 'Survey 5/2, Whitefield Main Road, SH 35, Sathya Sai Layout, Whitefield, Sathya Sai Layout, Whitefield, Bengaluru, Karnataka 560066',
#                 'Thubarahalli Extended Road, Kumarapalli, Thubarahalli, Whitefield, Bengaluru, Karnataka 560066',
#                 'Victorian View Layout, Silicon Valley, Borewell Road, Palm Meadows, Whitefield, Bengaluru, Karnataka 560066',
#                 'near Sri Veeranjenaya Swamy Temple,, Narayanappa Garden, Whitefield, Bengaluru, Karnataka 560066']),
#  '560078"': set(['" #309, 100 Feet Ring Road, Above Pizza Hut Near Delmia Cricle 2 Floor JP, Nagar, 5th Ph, JP Nagar Phase 6, JP Nagar, Bengaluru, Karnataka 560078"']),
#  '560080"': set(['" No. 40/43, 8 Main Raod, 5th Cross Road, Sadashiva Nagar,, Bhadrappa Layout, Sadashiva Nagar, Armane Nagar, Bengaluru, Karnataka 560080"']),
#  '560086': set(["5th-x, Mahalaxmi Layout, Mahalaxmi, KG Halli, D' Souza Layout, Ashok Nagar, Bengaluru, Karnataka 560086"]),
#  '560087': set(['Whitefield-Sarjapur Road, Opposite Chrysalis School, Varthur, Gunjur Village, Bengaluru, Karnataka 560087']),
#  '560093': set(['58, 8th Cross, Kaggadasapura Main Rd, C.V. Raman Nagar, Aishwarya Lake View Residency, Kaggadasapura, Bengaluru, Karnataka 560093']),
#  '560094"': set(['" No 3, Sapthagiri Janardhan Sun City, Seenappa Layout,New Bel Road, Bhadrappa Layout, Jaladarsini Layout, R.M.V. 2nd Stage, Bengaluru, Karnataka 560094"']),
#  '560100"': set(['" 2nd Floor, CNR Complex, Sampige Nagar Road, Glass Factory Layout, Electronic City, Vaddara Palya, Karnataka 560100"']),
#  '6': set(['HSR Layout Sector 6']),
#  '919739786600': set(['91 9739495000      919739786600']),
#  'AREA,Whitefield': set(['EPIP AREA,Whitefield']),
#  'ATM,Indiranagar': set([', CMH Road, Near ICICI Bank ATM,Indiranagar']),
#  'Addevishwanathapura': set(['Addevishwanathapura']),
#  'Adugodi': set(['AK Colony, Adugodi',
#                  'Basavanna Temple Road, AK Colony, Adugodi',
#                  'Corporation Complex,1st Floor, Hosur-Lashkar Road, Near-Vijaya Bank, Adugodi',
#                  'Hosur Rd, Ayappa Garden, Adugodi',
#                  'Hosur Rd, Nanjappa Layout, Adugodi',
#                  'Laksar Hosur Road, Adugodi',
#                  'Opp Christ University, Before Forum Mall, Hosur Main Road, Chikku Lakshmaiah Layout, Adugodi']),
#  'Agrahara': set(['Parappana Agrahara',
#                   'Virat Nagar Main Road, Roopen Agrahara']),
#  'Agrahara,': set(['10 pampa extension, Kempapura Agrahara,']),
#  'Akshayanagar': set(['Akshayanagar']),
#  'Ambalipura': set(['Haralur Rd, Ambalipura', 'Haralur Road, Ambalipura']),
#  'Apartments': set(['Janadhar Subha Apartments']),
#  'Apartments,': set(['Plot No.34, Kempapura, Kempapura - Yemlur Main Road, Nr.Rohan Jharoka Apartments,',
#                      'Shriram Spandhan Apartments,']),
#  'Apt': set(['Dodanakundi, Next to Alpine Eco Apt']),
#  'Area': set(['1st Main Road, EPIP Area',
#               '2nd Road, EPIP Industrial Area',
#               '4th B Cross, 5th Block, Koramangala Industrial Area',
#               '4th Phase, 12th Cross, Peenya Industrial Area, Peenya Industrial Area',
#               'Bommasandra Jigani Link Rd, Off Hosur Road, Bommasandra Industrial Area, Bommasandra Industrial Area',
#               'EPIP Area',
#               'Junior College Road, Kadugodi Industrial Area',
#               'KIADB Industrial Area',
#               'Kssidc Industrial Area',
#               'Near Bostik India Private Limited, Kachanayanahalli,, Bommasandra Industrial Area',
#               'Near R N S Motors, GB Palya, Hosur Road, Near Bommanahalli Signal, Bommasandra Industrial Area',
#               'Whitefield Road, Vishueswaraya Industrial Area']),
#  'Area,': set([', Bommasandra Jigani Link Road, Bommasandra Industrial Area,',
#                'Site No. 1A, 4th Phase, Jigani Link Road, Bommasandra Ind. Area,']),
#  'Area,Whitefeld': set(['EPIP Area,whitefield;EPIP Area,Whitefeld']),
#  'Area,Whitefield': set(['EPIP Area,Whitefield']),
#  'Area,Whitefiled': set(['EPIP Area,Whitefiled']),
#  'Area,whitefeild': set(['EPIP Area,whitefeild']),
#  'Area,whitefield': set(['EPIP Area,whitefield']),
#  'Arekempenahally': set(['Arekempenahally']),
#  'Arekere': set(['2nd Main Road, Arekere', 'Nyanappana Halli, Arekere']),
#  'Arekere,': set(['40th Rd, Royal Residency Layout - BTM 4th stg, Royal Residency Layout, Arekere,']),
#  'Attiguppe': set(['7 Subbanna Garden Vijaynagar, Attiguppe',
#                    'Adichunchangiri Shopping Complex Adichunchangirishpgcplx Vjyngrb40 Vijaynagar, Attiguppe']),
#  'Avalahalli': set(['Avalahalli']),
#  'BANGALORE': set(['7TH CROSS RAMAGONDAHALLI BANGALORE',
#                    'HOSUR ROAD, KORAMANGALA, BANGALORE',
#                    'KORAMANGALA BRANCH, BANGALORE']),
#  'BTM': set(['13th Main Road, 2nd Stage, BTM']),
#  'Bakery': set(['No.50/A, G.B Palya, Hosur Road, Opposite vrunda Bakery']),
#  'Banasawadi': set(['Banaswadi Main Rd, Banasawadi']),
#  'Banashankari': set([',2nd Main,1st Block,4th Phase,Kathriguppe,BSK 3rd Stage, Water Tank Road, Banashankari',
#                       '12th Main Road, Bank Colony Circle, Beside NIIT, BSK 1st Stage, 80 Feet Rd, Banashankari',
#                       '13th Main Srinagar, Banashankari',
#                       '1st Floor, 10th Main, 2nd Block, Srinivas Nagar, Near Ayyappaswamy Temple, Banashankari Stage I, Banashankari',
#                       '1st floor, Ittamadu main road, Ittamadu, Banashankari 3rd Stage, Banashankari',
#                       '20th Main Road, Muneshwara Block, Girinagar, 1st phase Girinagar, Kadavanthra, Banashankari',
#                       '4th Main Road, Chennamanakere Achukatte, BSK 3rd Stage, Banashankari',
#                       '7th Main, Near Panchami Chats, 80 Feet Rd, Banashankari Stage I, Srinivasnagar, Banashankari',
#                       '80 Feet Rd, Srinivasnagar, Banashankari',
#                       '80 Feet Road, 1st Stage, Srinivasa Nagar, Banashankari',
#                       '9th Main, Dr. Raj Road, Srinivasnagar, Banashankari',
#                       'BSK 1st Stage, Bank Colony, 80 Feet Rd, Srinivasnagar, Banashankari',
#                       'Ittamadu Main Road, Near-Reliance Fresh, Banashankari 3rd Stage, Ittamadu, Banashankari 3rd Stage, Banashankari',
#                       'Nagendra Block, 50ft Road, 10th Main Rd, Srinagar, Banashankari',
#                       'PES College Rd, Phase 1, Banashankari Stage I, Banashankari',
#                       'Sbm Colony, 80 Feet Road, Banashankari I Stage, Banashankari I Stage, 80 Feet Rd, Banashankari',
#                       'Siddanna Layout, 7th Block, Banashankari',
#                       'State Bank Of Mysore Colony, 1st Stage,80 Feet Road,, Banashankari']),
#  'Banashankari,': set(['10th Main, BSK 1st Stage, Banashankari Stage 1, Banashankari,',
#                        '80 Feet Rd, Srinivasnagar, Banashankari,',
#                        'BMS Plaza, First Floor, Opposite Kathriguppe Water Tank, 3rd Cross Rd, 1st Block, Banashankari 3rd Stage, Banashankari,',
#                        'Banashankari,']),
#  'Banaswadi': set(['1st Floor, 1st Cross, Banswadi Main Road, Dodda Banaswadi',
#                    '3rd Cross Road, Near Maruthi School Bus Stop, Erappa Layout, Subbaiahna Palya, Banaswadi',
#                    '3rd Floor, Banaswadi Main Road, Banaswadi',
#                    '5 Bhuvanagiri, OMBR Layout, Banaswadi',
#                    '6th cross, vijaya bank colony main road, Dodda Banaswadi',
#                    'Banaswadi',
#                    'Banaswadi Main Road, Banaswadi']),
#  'Bangalore': set(['13th Cross, Service Road, 6th Sector, Hsr Layout, Bangalore',
#                    '15 th Cross, RHCS Layout, Annapoorneshwari Nagar, Nagarbhavi 2nd Stage, Bangalore',
#                    '2nd Floor, 13th Cross, Service Road, 6th Sector, Hsr Layout, Bangalore',
#                    '80 Feet Road, Koramangala, Bangalore',
#                    '80 Feet Road, Opp Adyar Anand Bhavan, Koramangala, Bangalore',
#                    '80Feet Road, Koramangala, Bangalore',
#                    'B.T.S Main Road, Wilson Garden, Bangalore',
#                    'BTM Layout Stage 2, Bangalore',
#                    'Bangalore Central, Outer Ring Road, Bellandur, Bangalore',
#                    'Bellandur, Bangalore',
#                    'Beside Symphony Teleca Building, Whitefield,, Bangalore',
#                    'Bommanahalli, Bangalore',
#                    'C.V Raman Nagar, Byrasandra, Bangalore',
#                    'Forum Mall, Hosur Road, Koramangala, Bangalore',
#                    'Forum Mall, Koramangala, Bangalore',
#                    'Forum mall, koramangala, Bangalore',
#                    'Green Glen Layout, Bellandur, Bangalore',
#                    'Hosur Road, Koramangala, Bangalore',
#                    'In Forum Mall, Koramangala, Bangalore',
#                    'Inside Forum Mall, Koramangala, Hosur Road, Bangalore',
#                    'Kadubisenehalli, Bangalore',
#                    'Koramanagala, Bangalore',
#                    'Koramangala, Bangalore',
#                    'M.M Road, Frazer Town, Bangalore',
#                    'Marathahalli, Outer ring road, Devarabisenahalli, Bellandur, Kadubisenahalli, Bangalore',
#                    'Near BOSCH Back Gate, Koramangala, Bangalore',
#                    'Near Forum Mall, Koramangala, Bangalore',
#                    'Near SonyWorld Signal, Koramangala, Bangalore',
#                    'Opp Vijaya Bank, Bannerghatta Road, Bangalore',
#                    'Opposite Prestige Tech Park, Marathahalli, Outer Ring Road, Kadubisanahalli, Marathahalli, Bangalore',
#                    'Palace Arcade, S C Road, Bangalore',
#                    'Rupena Agrahara, Hosur Road, Bangalore',
#                    'Sarjapur Outer Ring Road, Bellandur, Bangalore',
#                    'Spencer Road, Fraser Town, Bangalore',
#                    'Subedar chatram road, Bangalore',
#                    'near Sony World signal, Koramangala, Bangalore']),
#  'Bangalore-66': set(['#172, EPIP Zone, Phase 2, Whitefield Road, Bangalore-66']),
#  'Bank': set(['Sri Thimappa Complex, Old Madras Road, KR Puram, Below Syndicate Bank',
#               'Sunrise Towers, 30th crs JP Rd. Girinagar.,opp Canara Bank']),
#  'Banswadi': set(['Nehru Road, Kullappa Road, Near-Kullapa Circle, Kammanahalli, PNS Layout, Subbayianiah Palyam, Banswadi']),
#  'Basavanagud': set(['Mallaraiah Complex, 1st Floor, Gandhi Bazaar Main Rd, Gandhi Bazaar, Basavanagud']),
#  'Basavanagudi': set(['1st Floor, GR Plaza, DVG Road, Gandhi Bazaar, Basavanagudi',
#                       '2nd Main, Near-SBI, Basavanagudi',
#                       '3rd Cross Rd, Basavanagudi',
#                       '3rd Floor, Above Reliance Trends, 10, Gandhi Bazaar Main Rd, Basavanagudi',
#                       '3rd Floor, Gandhi Bazaar Main Road, Gandhi Bazaar, Basavanagudi',
#                       'Aaradya Complex, 21/1, Vanivilas Road, Near-National College, Basavanagudi',
#                       'Bull Temple Rd, Gavipuram Extn, Gandhi Bazaar, Basavanagudi',
#                       'Bull Temple Road, NR Colony, Basavanagudi',
#                       'Bull Temple Road, Near-Bull Temple, Basavanagudi',
#                       'DVG Road, Basavanagudi',
#                       'DVG Road, Gandhi Bazaar, Basavanagudi',
#                       'E Anjaneya Temple St, NR Colony, Basavanagudi',
#                       'Gandhi Bazaar Main Rd, Gandhi Bazaar, Basavanagudi',
#                       'Gandhi Bazaar Main Road, Basavanagudi',
#                       'Gandhi Bazaar, Basavanagudi',
#                       'Gandhi Bazar Main Road, Basavanagudi',
#                       'Gandhibazar, Basavanagudi, Basavanagudi',
#                       'Govindappa Road, V.C Plaza, Next To Suvarna Silk, DVG Road, Gandhi Bazaar, Basavanagudi',
#                       'Kanakapura Rd, Basavanagudi',
#                       'Kanakpur Road, Basavanagudi',
#                       'Kankapura Road, Yediyur, Basavanagudi',
#                       'Lakshmi Tower, R V Road, Basavanagudi, Near South End Circle, Basavanagudi',
#                       'Model House Street, Basavanagudi',
#                       'Next to cake ghar,Gandhi Bazaar Main Rd, Gandhi Bazaar, Basavanagudi',
#                       'Nittoor Bhavana, S Kariyappa Road, Basavanagudi',
#                       'Patalamma Street, Basavanagudi',
#                       'RV Road, South End Circle, Opp Bangalore Hospital, Basavanagudi',
#                       'S End Rd, Basavanagudi',
#                       'S End Rd, Yediyur, Basavanagudi',
#                       'S Kariyappa Road, Basavanagudi',
#                       'V V Puram College of Science, Parvathipuram, Basavanagudi',
#                       'Vanivilas Rd, Basavanagudi']),
#  'Basavangudi': set(['Basavangudi', 'K R Road, Basavangudi']),
#  'Basavangudi,': set(['7th Cross Road, NR Colony, Basavangudi,']),
#  'Basaveshwaranagar': set(['15th Main, 3rd Stage, Basaveshwaranagar',
#                            '1st Main Basaveshwaranagar',
#                            '1st main Basaveshwaranagar',
#                            'Basaveshwaranagar',
#                            'Shamavana, 4th B Main, III Block, Basaveshwaranagar']),
#  'Basaveshwarnagar': set(['6 main Basaveshwarnagar']),
#  'Battarahalli': set(['Shop No.2,T.C.Playa, Opp.Bharath Petroleum, Sonnathammanahalli K.R.Puram, Anandapura, Battarahalli',
#                       'Venkatadri Complex, Above Cafe Coffee Day, Battarahalli, Old Madras Road, Bhadrappa Layout, Sannatammanahalli, Battarahalli']),
#  'Bazaar': set(['Puttana Rd, Gandhi Bazaar']),
#  'Bazar': set(['Gandhi Bazar',
#                'Kathriguppa main road, 3rd Stage, Opposite Big Bazar']),
#  'Be': set(['Piritech Park (SEZ), Adarsh Palm Retreat, Be']),
#  'Belandur,': set(['Campus 4A, PrITech Park (Ecospace), 7th and 8th Floor, Belandur,']),
#  'Bellandu': set(['7th Cross Road, Yemalur, Bellandu',
#                   'Devarabisanahalli, Bellandu']),
#  'Bellandur': set(['"2nd Floor, 5A Block, Pritech Park  SEZ, Pritech Rd, Bellandur',
#                    '"Devarabisanahalli, Bellandur',
#                    '"PRItech Park, Bellandur',
#                    '"PrItech Park, Bellandur',
#                    '"RMZ Ecospace Internal Rd Adarsh Palm Retreat, Bellandur',
#                    '"RMZ Ecospace Internal Rd, Adarsh Palm Retreat, Bellandur',
#                    ', Piritech Park (SEZ), Phase 1,  Campus 5B, 1st Floor, Bellandur',
#                    '1B, Ecospace, Outer Ring Road, Off RMZ Ecospace Internal Rd,, Adarsh Palm Retreat, Bellandur',
#                    '4th Cross, Yemalur, Bellandur',
#                    '52/2, 52/3, Marathahalli, Sarjapura outer ring road, Devarabisanahalli, Bellandur',
#                    '5th Main, Agara Post, Sarjapur Main Rd, Ibbaluru, Iblur Village, Bellandur',
#                    '7th Floor, Sony Building, 2B Tower 3,  Embassy Tech Village, Devarabisanahalli,  Bellandur',
#                    'Adarsh Palm Retreat, Adarsh Palm Retreat, Bellandur',
#                    'Adarsh Palm Retreat, Bellandur',
#                    'Adarsh Palm retreat,, Bellandur',
#                    'Agara Post, Sarjapur Main Rd, Iblur Village, Bellandur',
#                    'Agara, Service Rd, Iblur Village, Bellandur',
#                    'Agra, Service Rd, Iblur Village, Bellandur',
#                    'Behind RMZ Ecospace Marathahalli-Sarjapur Outer Ring Road, Bellandur',
#                    'Bellandur',
#                    'Bellandur Lake Rd, Kariyammana Agrahara, Bellandur',
#                    'Belur Nagasandra, Bellandur',
#                    'Building 12B, RMZ Ecospace Internal Rd, Bellandur',
#                    'Campus 1B EcoSpace Varthur Hobli Sarjapura Villas,, Service Rd, Adarsh Palm Retreat, Bellandur',
#                    'Devarabisanahalli, Bellandur',
#                    'Iblur Junction, Near Shoba Garnet, Outer Ring Road, Sarjapur Main Rd, Iblur Village, Bellandur',
#                    'Iblur Village, Bellandur',
#                    'Kariyammana Agrahara Rd, Kariyammana Agrahara, Bellandur',
#                    'Kariyammana Agrahara Rd, Yemalur, Bellandur',
#                    'Marathahalli - Sarjapur Outer Ring Rd, Iblur Village, Bellandur',
#                    'Marathahalli, Sarjapura outer ring road, Devarabisanahalli, Bellandur',
#                    'Margosa Avenue, Green Glen Layout, Bellandur',
#                    'Marshal Lakeview Apartments, 6th Main Rd, Iblur Village, Bellandur',
#                    'Next to Sobha Garnet Road, Drapes View, Sarjapur Main Rd, Iblur Village, Bellandur',
#                    'Outer Ring Road, Bellandur',
#                    'Outer ring road, Bellandur',
#                    'Pritech Park, Ecospace Business Park, RMZ Ecospace, Internal Rd, Campus 4A Block, 4th Floor, Bellandur',
#                    'RMZ Eco World Road, Adarsh Palm retreat,, Bellandur',
#                    'Rd, Iblur Village, Bellandur',
#                    'Sarjapur Main Rd, Bellandur',
#                    'Sarjapur Main Rd, Iblur Village, Bellandur',
#                    'Sarjapur Main Road, Iblur Village, Bellandur',
#                    'Sarjapur Road Bellandur Gate, Bellandur',
#                    'Second Floor, RMZ Ecospace, Marathahalli-Sarjapur Outer Ring Rd, Bellandur',
#                    'Service Rd, Agara, Iblur Village, Bellandur',
#                    'Service Rd, Iblur Village, Bellandur',
#                    'Shop No. 1, Ring Road, Sarjapur Main Rd, Iblur Village, Bellandur',
#                    'Sobha Garnet, Iblur Village, Bellandur',
#                    'Sobha Mayflower, Outer Ring Road, Bellandur',
#                    'Yemalur Main Rd, Yemalur, Bellandur',
#                    'Yemalur, Bellandur',
#                    'campus 4A & 4B, 10th & 11th Floor,  RMZ Ecoworld, RMZ Eco World Rd, Adarsh Palm Retreat , Bellandur',
#                    'central mall  Bellandur']),
#  'Bellandur,': set(['"4A Block, 6th Floor, RMZ Ecospace, Outer Ring Road, Marathahalli, Bellandur,',
#                     '"6B, Adarsh Palm Retreat,  Adarsh Palm Retreat, Bellandur,',
#                     '"Piritech Park (SEZ), Phase 1,  RMZ Ecospace Internal Rd,  Adarsh Palm Retreat, Bellandur,',
#                     '"Pritech Park, Bellandur,',
#                     '"Pritech Rd, Adarsh Palm Retreat,  Bellandur,',
#                     ',Kumar I Life Apartment,  Near Country Club,Bangalore, Bellandur,',
#                     '4A Ecospace,, RMZ Ecospace Internal Rd, Bellandur,',
#                     'Bellandur - Doddakannelli Rd, Bellandur,',
#                     'Bellandur Main Road, Bellandur,',
#                     'Building 12B, RMZ Ecospace Internal Rd, Bellandur,',
#                     'Devarabisanahalli, Bellandur,',
#                     'GVR Plaza, Outer Ring Road, opposite Central Mall, Bellandur,',
#                     'Kaadubeesanahalli Rd, Devarabisanahalli,  Bellandur,',
#                     'Kariyammana Agrahara Rd, Yemalur, Bellandur,',
#                     'Marthahalli, Sarjapura outer ring road, Devarabisanahalli, Bellandur,',
#                     'Panathur, Chandana, Devarabisanahalli, Bellandur,',
#                     'Piritech Park (SEZ), Phase 1,  Campus 5B, 1st Floor, Bellandur,',
#                     'RMZ Ecoworld, Bellandur,',
#                     'Sarjapur Main Rd, Iblur Village, Bellandur,',
#                     'Suraamy Plaza, Outer Ring Road Bellandur, Bellandur,',
#                     'Yemalur Main Rd, Yemalur, Bellandur,',
#                     'Yemalur, Bellandur,',
#                     'mathru Sree Orchid Homes, 4, Kempapura Main Rd, Kempapura, Bellandur,']),
#  'Bellandur\\': set(['Yemalur, Bellandur\\']),
#  'Bengalur': set(["20th Main, 2nd Cross, 1st Stage, BTM Layout, Next to Friend's Hotel, Aicobo Nagar, 1st Stage, BTM Layout, Bengalur",
#                   'Mount Joy Road, Hanumanth Nagar, Gavipuram Extn, Basavanagudi, Bengalur']),
#  'Bengaluru': set([', 11th Cross Rd, Malleshwaram, Bengaluru',
#                    ',Inner Ring Road, Amarjyoti Layout, Domlur, Krishna Reddy Layout, Amarjyoti Layout, Bengaluru',
#                    '100 Feet Road, Hal 2nd Stage, Indiranagar, Bengaluru',
#                    '10th Cross Rd, Yalappa Garden, Malleshwaram, Bengaluru',
#                    '12th Main Road,  Kothanur Main Road, J.P. Nagar, 7 Phase, Bengaluru',
#                    '12th Main, Near Navarang Theatre, Rajajinagar, Bengaluru',
#                    '16th main, 3rd Block, Koramangala, Bengaluru',
#                    '17th Cross, Sector 7, HSR Layout, Bengaluru',
#                    '1st Main Road, Near-S K Jewellers, Yeshwanthpur, Bengaluru',
#                    '27th Main, Sector 1, Behind-Titan Eye, Hsr Layout, Bengaluru',
#                    '3G Homes Crimson Layout, Kadugodi, Bengaluru',
#                    '3rd Floor, No.14, Pottery Rd, Bhadrappa Layout, Richards Town, Bengaluru',
#                    '6th Cross Rd, HAL 3rd Stage, Kodihalli, Bengaluru',
#                    'A.M. Lane, B.V.K. Street, Chik Pet, Huriopet, Chickpet, Bengaluru',
#                    'Banaswadi Main Road, Banaswadi Layout, Maruthi Sevanagar, Bengaluru',
#                    'Bellary Road, Vishveshvaraiah Nagar, Ganga Nagar, Bengaluru',
#                    'Bengaluru',
#                    'Bhaskar Reddy Building, Somasundrapalya Junction, HSR Layout 2nd, HSR Layout, 2nd Sector,, Garden Layout, Sector 2, HSR Layout, Bengaluru',
#                    'Ground Floor Parking, Block,UB City, Concorde, 24, Vittal Mallya Road, KG Halli, Shanthala Nagar, Ashok Nagar, Bengaluru',
#                    'HAL 2nd Stage, Indiranagar, Bhadrappa Layout, Sodepur, Appareddipalya, Indiranagar, Bengaluru',
#                    'ITPL Main Road, EPIP Zone, Whitefield, Bengaluru',
#                    'Kothnur Village Main Rd, Gaurav Nagar, JP Nagar 7th Phase, JP Nagar, Bengaluru',
#                    'Marathahalli Outer Ring Road, Above Elite Ford, Bengaluru',
#                    'Marathahalli Outer Ring Road, Bengaluru',
#                    'Marathahalli-Sarjapur Outer Ring Road, Marathahalli, Bengaluru',
#                    'Near Central Silk Board Junction Next to The Oxford, Bengaluru',
#                    'Near Frank Anthony Public School,, 17/1, Cambridge Road, Halasuru, Bhadrappa Layout, Udani Layout, Ulsoor, Bengaluru',
#                    'Near Home Town, Outer Ring Rd, Marathahalli, Bengaluru',
#                    'Opp  to Multiplex, Marathalli Munenkollal, Outer Ring Rd, Bengaluru',
#                    'Sahakara Nagar Main Rd 2nd floor Century Corbel Commercial Sahakaranagar, Bhadrappa Layout, Park View Layout, Bengaluru',
#                    'Silver Springs Layout, Marathahalli, Bengaluru',
#                    'Unit No 48 To 51, S P A Plaza, Ground Floor, Near-Shardha Talkies, Otc Road, Halsurpete, Nagarathpete, Bengaluru',
#                    'Whitefield Main Road, Mahadevpura, Devasandra Industrial Estate, Krishnarajapuram, Bengaluru']),
#  'Bengaluru,': set(['1st A Cross Rd, 5th Block, Koramangala, Bengaluru,',
#                     '1st Main 1st Block, Koramangala, S.T. Bed, 1st Block Koramangala, Bengaluru,',
#                     '24th Main Rd, Vanganahalli, 1st Sector, HSR Layout 5th Sector, Bengaluru,',
#                     '4/1, Kammanalli Main Road, Opp. Jal Vayu Vihar, Bhadrappa Layout, Sena Vihar, Kammanahalli, Bengaluru,',
#                     '50/A, Kalasipalyam Main Rd, K. R. Market, Kalasipalayam, Bengaluru,',
#                     '5th Main Road, 6th Cross, Malleshpalya, Bhadrappa Layout, Malleshpalya, Kaggadasapura, Bengaluru,',
#                     '7th Cross, 1st & 2nd Floor, Near Kalamandir, Marathahalli, Anand Nagar, Aswath Nagar, Marathahalli, Bengaluru,',
#                     'Banaswadi Main Road, Banaswadi Layout, Maruthi Sevanagar, Bengaluru,',
#                     'Chandra Layout, Marathahalli, Bengaluru,',
#                     'DAS Commercial Complex, JSS Circle,, 7th Block Jayanagar, 7th Block, Jayanagara Jaya Nagar, Bengaluru,',
#                     'GR Complex, Old Airport Road, Domulur, Bhadrappa Layout, BDA Colony, Domlur Village, Domlur, Bengaluru,',
#                     'Infantry Road, Shivaji Nagar, Bengaluru,',
#                     'Kempanna Rd, Vignan Nagar, BTM Dollars Scheme, Basavanagar, Bengaluru,',
#                     'MCC Arcade , 2nd Floor. Near Sigma Tech Park,, Varthur Main Rd, Ramagondanahalli, Whitefield, Bengaluru,',
#                     'Mosque Rd, Bhadrappa Layout, Pulikeshi Nagar, Bengaluru,',
#                     'Murugesh Pallya, Nanja Reddy Colony, Jeevanbheemanagar, Bengaluru,',
#                     'The Residency , 133/1, Residency Road, Opposite Bipshop Cotton High School, Bhadrappa Layout, Shanthala Nagar, Ashok Nagar, Bengaluru,',
#                     'opposite Photo Flash, Millers Rd, Bhadrappa Layout, Kaverappa Layout, Vasanth Nagar, Bengaluru,']),
#  'Bhattarahalli,': set(['bidrahalli Post, Bhattarahalli,']),
#  'Bilekahalli': set(['Bannerghatta Road, Near Kalyani Kala Mantap, Bilekahalli, 2nd Cross Rd,, Ram Shetty Nagar, Bilekahalli']),
#  'Block': set([', Aswan Plaza, 20th Main, Koramangala 8th Block',
#                ', New no.5/1, Jayanagar 9th Block',
#                '100 feet road, Koramangala 4th Block',
#                '11A Main, Jayanagar 5th Block',
#                '17TH F1 Main Rd, Koramangala 6 Block',
#                '1st Floor, Lakshmi Venkateshwara Arcade, 11th Main Road, Off 33rd Cross Road, Opp. KFC, Jayanagar 4th Block',
#                '26th Main Road, 4th T Block East, Jayanagara 9th Block',
#                '46th cross, Rajajinagar 4th Block',
#                '5th Main Cross Road, HRBR Layout Kalyan Nagar 2 Block',
#                '60 Feet Road,6th Block, Koramangala 6th Block',
#                '6th Block, Opp Koramangala Bus Depot,Koramangala, 6th Block',
#                '6th Main Krishnappa Block',
#                '80 Feet Road, 5th Block',
#                '80 Feet Road, Koramangala 4th Block',
#                'AECS Layout, B Block',
#                'Dr Rajkumar Rd, 4N Block',
#                'H B R Layout, 3rd Block',
#                'JP Nagar 8th Phase 2nd Block',
#                'Jayanagar 1st Block',
#                'KHB Colony, Next To Mangala Kalyana Mantapa 5th Block Adugodi Road, Koramangala 8th Block',
#                'Kammanahalli Main Road, HRBR Layout 2nd Block',
#                'Koramangala 5th Block',
#                'Koramangala, Koramangala 4th Block',
#                'Near-IBP Petrol Bunk, 6th D Cross Road, Koramangala 6th Block']),
#  'Block,': set([', 26th Main, Jayanagar 9th Block,',
#                 ', 4th Cross, Koramangala 7th Block,',
#                 '14th Main,50th Cross, Rajajinagar 3rd Block,',
#                 '2th Floor, Balavana 5th A Block, Koramangala 5th Block,',
#                 '6th Cross, Venkatapura Main Road, Koramangala 1st Block,',
#                 'Ground floor, 8th E Main road, Jayanagar 4th Block,']),
#  'Block,Rajajinagar,': set(['19th Main, 9th Cross, 1st Block,Rajajinagar,']),
#  'Bommanahall': set(['Hosur Road, Next to Oxford College, Salarpuria Greenage Internal Road, Bommanahall']),
#  'Bommanahalli': set([', Begur Main Road, Bommanahalli',
#                       ', garvebhavi palya, Hosur main road, Bommanahalli',
#                       '1st Cross, B Block, Vishwapriya Nagar, Begur Main Road, Bommanahalli',
#                       '1st Floor, BVNR Complex, Hosur Main Road, Bommanahalli',
#                       'Rupena Agrahara, Bommanahalli',
#                       'Vivekananda Nagar, 4th Cross, Begur Road, Bommanahalli, Bommanahalli',
#                       'Vivekananda Nagar, Bommanahalli']),
#  'Bommanahalli,': set(['ATM, Bommanahalli Village, Begur, Bommanahalli,']),
#  'Bridge': set([',M T K Reedy Building, Below Krishna Vaibhava Hotel, Marathahalli, Bridge']),
#  'Bridge)': set(['Airport Road (Near Marathahalli Bridge)',
#                  'HAL Airport Road (near Marathahalli Bridge)']),
#  'Brookefield': set(['BEML Layout, Brookfield Main Road, Kundanahalli Village, BEML Layout, Brookefield',
#                      'EPIP Zone, Brookefield',
#                      'Pearlwood Building, Ganesh Temple Road, AECS Layout, Brookefields, AECS Layout - A Block, AECS Layout, Brookefield',
#                      'Sita Lakshmi ITPL Rd, AECS Layout - A Block, AECS Layout, Brookefield',
#                      'Varthur Main Rd, Chaitanya La Grove, Brookefield']),
#  'Brookefield,': set(['ASK Towers, ITPL Main Road, Kundalahalli, E Block, AECS Layout, Brookefield,',
#                       'Fitness One Brookefield, AECS Layout - C Block, AECS Layout, Brookefield,',
#                       'ITPL Main Road, Kundalahalli, Brookefield,']),
#  'Brookfield': set(['Kundanahalli Cross Road, Brookfield']),
#  'Buildings': set(['Near Vasmani Group Buildings']),
#  'Byrasandra,': set(['Anjaneya Swami Temple Road, Byrasandra,']),
#  'Byrathi': set(['1st cross, 1st B Main Road, Kanakashree Layout, Byrathi']),
#  'CHEMICALS': set(['No 24/1, Tumkur Road Anchepalya , Nagasandra, Near PONPURE CHEMICALS']),
#  'Care': set(['11th Cross, Vyalikaval, Near-Sukruthi Eye Care',
#               'CMR Road, HRBR Layout, Kalyan Nagar, Next To Vasan Eye Care']),
#  'Challaghatt': set(['Challaghatta junction, Challaghatt']),
#  'Challaghatta': set(['Challaghatta',
#                       'Challaghatta Jct Rd, Challaghatta',
#                       'Embassy Golf Links Business Park, Challaghatta',
#                       'Inner Rd, Embassy Golf Links Business Park, Challaghatta',
#                       'Pine Valley, Inner Rd, Embassy Golf Links Business Park, Challaghatta',
#                       'Shriram Spandana, Near Embassy Golk Links, Challaghatta',
#                       'Sriram Spandhana Apartments, Wind Tunnel Road, Challaghatta']),
#  'Challaghatta,': set(['4th Floor, Pine Valley, Embassy Golf Links Business Park,  Challaghatta,',
#                        'Challaghatta Jct Rd, Challaghatta,',
#                        'Embassy Golf Links Business Park, Challaghatta,',
#                        'Embassy Golf Links Road, Embassy Golf Links Business Park, Challaghatta,']),
#  'Challaghatta,Yemlur-Post': set(['Challaghatta Main Road, Challaghatta,Yemlur-Post']),
#  'Chamarajpet': set(['1st Cross, 5th Main, Chamarajpet',
#                      '1st Floor, 9th Cross, 1st Main Road, Chamarajpet',
#                      'No.40, 2nd Cross, Chamarajpet']),
#  'Chamarajpet,': set(['20, 2 Cross 5 Main, Nanjamba Agrahara, Chamarajpet,']),
#  'Chamrajpet,': set(['668/12, 1st Floor Durugal Mutt Road V V Puram, Near-Apex Bank, Chamarajpet, Chamrajpet,']),
#  'Chandapura': set(['Bommasandra Indl Area, Hosur Main Road, Next To Narayan Hrudayalaya, Chandapura']),
#  'Chansandra': set(['Chansandra']),
#  'Chelekare': set(['1st Floor, L.G.R. Complex, Outer Ring Rd, Chelekare']),
#  'Chennai,': set(['Gandhi Nagar, Devi Karumariamman Nagar, Velachery, Chennai,']),
#  'Chickpet': set(['1, Majestic Circle, Near Arya Bhavan Sweets, K G Sweets, Gandhi Nagar, Gandhi Nagar, Bhadrappa Layout, Balepete, Chickpet',
#                   '37/2, K V Temple Road, Opposite-Charan Bank, Santhusapet, Chickpet',
#                   'Dasappa Building, Dasappa Lane, Chikpet, Anchepet, Chickpet',
#                   'Laxman Rao Road, Balepet Cross, Near-Garden English School, Chickpet, Basettypet, Huriopet, Chickpet']),
#  'Chickpet,': set(['Laxman Rao, 63, BVK Iyengar Rd, Basettypet, Huriopet, Chickpet,']),
#  'Chikkakannalli': set(['Off. Sarjapur Road, Chikanayakanahalli Village, Chikkakannalli',
#                         'Sarjapur Main Road, Carmelaram, Hadosiddapura, Chikkakannalli']),
#  'Chikkalasandra': set(['1st Main 2nd Cross Seven Hills Layout Chikkalasandra']),
#  'Chikkammanahalli': set(['Begur Koppa Road, Chikkammanahalli']),
#  'Chikpete,': set(['P S Lane Santhusapet, Chikpete,']),
#  'Chokkanahalli': set(['Thanisandra Main Road, Chokkanahalli']),
#  'Circle': set(['Ashoka Pilla Circle',
#                 'Christ School Road, SaddaguntePalya, Dairy Circle',
#                 'ITPL Main Road, near Hoodi Circle',
#                 'Inner Circle',
#                 'Krishna Rajendra Circle',
#                 'Netta Kalappa Circle',
#                 'No.176/177, Mysore Road, Near Mysore Road Circle',
#                 'Outer Circle',
#                 'Rani Sarla Devi Circle',
#                 'S. C. Road, Swastik Circle',
#                 'Sajjan Rao Circle']),
#  'Circle)': set(['Hoodi Main Road (Near Hoodi Circle)']),
#  'Cisco,': set(['"No 1, Adarsh Palm Retreat, Bellandur, Near Cisco,']),
#  u'Cit': set([u'S.R.T Alphines Luxurious Hotel, Narayana Hrudayalaya Hospital Road, Kithaganahali, Bommasandra,\xa0Electronic Cit']),
#  'City': set(['#11-A, 4th Cross, Veerasandra Industrial Area, Electronic City Phase II, Electronic City',
#               '1, KIADB, Bommasandra Industrial Area, Hosur Main Road,Electronic City',
#               '11th Cross, Mico Main Road, Hosur Rd, CK Nagar, Electronic City',
#               '3rd Cross, 1st Main Road, C.K Nagar, Electronic City, Chennakeshava Nagar, Hosa Road, Pragathi Nagar, Electronic City',
#               '3rd Phase, Near Narayana Hridhayalaya, Bommasandra, Electronic City',
#               u'Alphines Luxurious Hotel, Narayana Hrudayalaya Hospital Road, Kithaganahali, Bommasandra,\xa0Electronic City',
#               u'Anekal Road, Above Canara Bank, Chandapura,\xa0Electronic City',
#               'Avenue Road, Bangalore City',
#               'Biocon Limited, Corporate Office, 20th KM,, Hosur Main Road, Electronic City, Veer Sandra, Electronic City',
#               u'Bommansandra Industrial Area, Hosur Main Road,\xa0Electronic City',
#               'Bommasandra, Industrial Area, Hosur Road,Electronic City',
#               'Electronics City Phase 1, Electronic City',
#               u'Hennegara, Bommasandra,\xa0Electronic City',
#               'Hosa Road, Opposite Old RTO Office, Naganathapura Village, Electronic City',
#               u'Hypermarket, Neeladri Nagar Phase 1,\xa0Electronic City',
#               u'Kirloskar Road, Bommasandra Industrial Estate, Hebbagodi,\xa0Electronic City',
#               'Krishnapa Gowda Building, Near Wipro Gate 12, Electronic City',
#               'Legacy Building, Neeladri Layout, Electronic City',
#               u'Muni Reddy Building, Hosur Main Road, Bommasandra,\xa0Electronic City',
#               'Nandhi Shwetha Complex, Hennagara Gate, Hosur Road, NearElectronic City',
#               'Neotown, Neotown Road, Electronics City Phase 1, Electronic City',
#               u'Opposite Indus Ind Bank,Near Narayana Hrudayalaya Hospital, Bommasandra,\xa0Electronic City',
#               'Opposite Wipro Gate 12, Electronic City',
#               u'Opposite Wipro Technologies Gate 12,\xa0Electronic City',
#               u'Priyadarshini Petrol Bunk Complex, Near narayana Hrudayalaua Hospital, Hosur Road, Bommasandra Indl Area,\xa0Electronic City',
#               u'Ruchitha Complex, Anekal Road, Chandapura,\xa0Electronic City',
#               u'Service Road r BMTC Bus Stop,\xa0Electronic City',
#               u'Shanthipura Main Road, Near TCS Gate 1, Phase 2,\xa0Electronic City',
#               'The Lark Hotel, Hosur Main Road, Bommasandra Industrial Area,Electronic City',
#               'Velankani Drive Hotel Crowne Plaza, 43, Phase 1,Electronic City',
#               'Velankani Drive Opposite BHEL Side Gate, Velankanni Drive, Phase 1, Electronic City',
#               u'Velankani Tech park, Velankani Road, Dodda Thogur, Phase 1,\xa0Electronic City',
#               'Walton Road, Near UB City',
#               'th floor, Astra Hotel, Near Velankani Bus Stop, Phase 1,Electronic City']),
#  u'City,': set([u'Anekal Road, Above Canara Bank, Chandapura,\xa0Electronic City,',
#                 u'Concorde Anthurium, Next To Wipro Gate 16, Above Punjab National Bank, Neeladri Road, Phase 1,\xa0Electronic City,']),
#  'College': set(['3rd Main,Vidyamanyanagar West, Andrahalli Main Road, Vishwaneedam Near Acharya Polytechnic College',
#                  'Junction, Next to Kavcon Factory, Opposite to Rajarajeswari Dental College']),
#  'Colony': set([', 5th Main,Vijaya Bank Colony',
#                 '1st Cross KV Colony',
#                 '1st Cross, P&T Layout, Asheerwad Colony',
#                 '2nd Cross KV Colony',
#                 '2nd Cross LIC Colony',
#                 '6th Main Road Defence Colony',
#                 'Dollars Colony',
#                 'KHB Colony',
#                 'Lakshman Nagar, State Bank of India Colony',
#                 'Madhuban Colony',
#                 'RT Nagar Main Road,  80 Feet Main Road, P&T Colony',
#                 'Shan Boga Colony',
#                 'Shivalingaiah Colony']),
#  'Colony)': set(['West of Chord Road (LIC Colony)']),
#  'Complex': set(['BDA Complex',
#                  'SS Ashram Road, No. 1, 4th Main, Manjunatha Complex']),
#  'Complex,': set(['6th A Crs 3rd Blk, Behind Bda Complex,']),
#  u'Complex,\xa0Marathahalli': set([u'Purva Riviera Shopping Complex,\xa0Marathahalli']),
#  'Coral': set(['Sobha Coral']),
#  'Course)': set(['HAL Airport Road (Adjoining KGA Golf Course)']),
#  'Crescent': set(['Cunningham Crescent']),
#  'Cross': set([', 14th A Main Road, 1st Cross',
#                '10 Cross',
#                '10th Cross',
#                '10th Main, 15th Cross',
#                '11th Cross',
#                '11th Main Road,17th Cross',
#                '12 Cross',
#                '12th A Cross',
#                '12th Cross',
#                '12th Main,18th Cross',
#                '13th Cross',
#                '14th Cross',
#                '15 Cross',
#                '15th Cross',
#                '16th Cross',
#                '17th C Cross',
#                '17th Cross',
#                '17th D Cross',
#                '17th E Cross',
#                '17th F Cross',
#                '18th A Main, 5th Cross',
#                '18th Cross',
#                '19th Main, 5th Cross',
#                '1A Cross',
#                '1st Cross',
#                '1st Main, 1st Cross',
#                '22nd Cross',
#                '23rd Main Road, 21st Cross',
#                '25th  B Cross',
#                '27th Cross',
#                '29 Cross',
#                '29th C Cross',
#                '2C Cross',
#                '2nd A Cross',
#                '2nd B Cross',
#                '2nd C Cross',
#                '2nd Cross',
#                '30th Cross',
#                '33 Cross',
#                '36 Cross',
#                '39 Cross',
#                '3rd A Cross',
#                '3rd Block, Janapriya Township, Magadi Main Road, Kadabagere Post, Kadabagere,, Kaabagere Cross',
#                '3rd Cross',
#                '3rd E Cross',
#                '47th Cross',
#                '4th Cross',
#                '5th A Cross',
#                '5th Cross',
#                '5th E Cross',
#                '5th Main Road, 14th Cross',
#                '5th main, 13th Cross',
#                '6th Cross',
#                '7th Cross',
#                '7th Main 2nd Cross',
#                '8th Cross',
#                '9th Cross',
#                'AECS Naidu Layout 1st Cross',
#                'Brigade Road Cross',
#                'E V Lane, S P Road Cross',
#                'G R Lane, S p road Cross',
#                'Hutchins 2nd Cross',
#                'Hutchins 3rd Cross',
#                'Hutchins Road, 6th Cross',
#                'I G Cross',
#                'Lazar Road Cross',
#                'Mallesh Palaya 5th Main, 5th Cross',
#                'Mother Dairy Cross',
#                'South End C Cross',
#                'Udayanagara 2nd Cross',
#                'lazar Road Cross']),
#  'Cross)': set(['Sarakki Main Road (9th Cross)']),
#  'Cross,': set(['2, 3 Road K V Lane, Akkipet Cross, Akkipet Cross,',
#                 'E V Lane, S P Road Cross,']),
#  'Cross,Banashankari': set(['2nd Cross,Banashankari']),
#  'Cross,Malleshwaram': set(['17th Cross,Malleshwaram']),
#  u'Cross,\xa0Malleshwaram': set([u'Near MES College, 8th Main, 15th Cross,\xa0Malleshwaram']),
#  'Crossroad': set(['10A Crossroad']),
#  'Cubbonpet,': set(['Cubbon Park Road, Opposite-BBMP Office, Cubbonpet,']),
#  'Dasarahalli': set(['No.18, Magadi Main Road, 12th B Cross, Agrahara Dasarahalli']),
#  'Dasarahalli,': set(['S M Road, T Dasarahalli, Prashanth Nagar, T. Dasarahalli,']),
#  'Dattatreyanagar': set(['4th Main road Dattatreyanagar']),
#  'Day': set(['1st Floor, TMR Towers, Thubarahalli, Whitefield, Landmark: Above Coffee Day']),
#  'Deevarabeesanahalli': set(['Near Embassy Tech,  Marathahalli Outer Ring Road,  Deevarabeesanahalli']),
#  'Depot': set(['1M, Masand Esquire,Hennur Main Road, HRBR Layout 3rd Block, Opp Teachers Academy, Near Hennur Bus Depot',
#                'P.R Complex , 80 Feet Road, Koramangala 6th Block , Near Koramangala Bus Depot']),
#  'Devarabeesanahalli': set(['"#20 & 21, RMZ Ecoworld Infrastructure Pvt. Ltd.,  SEZ, Sarjapur Outer Ring Road, Near Intel Campus,  Devarabeesanahalli',
#                             'Tower 2D, Embassy Tech Village,  Outer Ring Road, Devarabeesanahalli']),
#  'Devarabeesanahalli,': set(['Embassy Tech Village 1 Building 2A,  Phase 2, East Wing, Third Floor,  Outer Ring Road, Devarabeesanahalli,']),
#  'Devarabisanahalli': set(['2nd Floor, Devarabisanahalli Main Road,  Outer Ring Rd, Devarabisanahalli',
#                            '7th Floor, Tower 2, 2B, Embassy Tech Village, Near New Horizon College, Devarabisanahalli']),
#  'Devarabisanahalli,': set(['Campus 1C, RMZ Ecospace, Sarjapur Outer Ring Road, Devarabisanahalli,',
#                             'West Tower, 3rd Floor, 2A,  Embassy Tech Village, Near New Horizon College,  Devarabisanahalli,']),
#  'Doddakannelli': set([', Gear Rd, Adarsh Palm Retreat,  Doddakannelli',
#                        'Adarsh Palm Retreat,  Kadubisanahalli, Doddakannelli',
#                        'Adarsh Palm Retreat, Kadubisanahalli, Doddakannelli',
#                        'Behind Adarsh Palm retreat,, Bellandur - Doddakannelli Rd,  Adarsh Palm Retreat, Doddakannelli',
#                        'Gear Rd, Adarsh Palm Retreat,  Doddakannelli',
#                        'Green Elegance Apartment,  Opposite Adarsh Palm Villas, Kaadubeesanahalli Rd,  Devarabisanahalli, Doddakannelli']),
#  'Doddakannelli,': set([', Gear Rd, Adarsh Palm Retreat,  Doddakannelli,']),
#  'Doddanakundi': set(['ORR Doddanakundi']),
#  'Doddanekundi': set(['Doddanekundi']),
#  'Doddathoguru': set(['Neeladri Rd, Electronics City Phase 1, Electronic City, Doddathoguru']),
#  'Domalur': set(['100ft road, indira nagar, HAL 2nd stage, Domalur']),
#  'Domlu': set(['1st Floor, PineValley, Embassy Golf Links Business Park,, Off Intermediate Ring Road, Domlu']),
#  'Domlur': set([', 1st Main Road, Domlur, 2nd Stage, Indiranagar, Bhadrappa Layout, Stage 2, Domlur',
#                 ', Embassy Golf Links Road, Embassy Golf Links Business Park, Domlur',
#                 '2nd Cross, 2nd Stage, 2nd Cross Rd, Stage 2, Domlur',
#                 'HAL Old Airport Rd, ISRO Colony, Domlur',
#                 'Pine Valley,  Embassy Golf Link Business Park,Off Intermediate Ring Road,  Domlur',
#                 'Prestige Tradent , Old Airport Road , Domlur',
#                 'Ring Road, Domlur',
#                 'Vasvani Layout, Challagatta Road, Domlur',
#                 'Vasvani Layout, Challaghatta Road, Next to Embassy Golf Link Business Park, Behind Hilton Hotel, Domlur']),
#  'Dommasandra': set(['Dommasandra',
#                      'Sarjapur Road, Dommasandra village, Dommasandra']),
#  'ENCLAVE': set(['THE DEFENSE ENCLAVE']),
#  'EPIP': set(['7th B Road, EPIP', 'EPIP']),
#  'EPIP,Area,Whitefield': set(['EPIP,Area,Whitefield']),
#  'EPIP,Whitefield': set(['EPIP,Whitefield']),
#  'East': set(['6th C main road, Jayanagar 4th Block East',
#               'Kumarakripa East',
#               'Pattalamma Temple Road, 3rd Block, Jaya Nagar East']),
# ...
#                      'Whitefield Main Rd, Sathya Sai Layout, Whitefield,']),
#  'Workshop': set(['2nd cross, 515 Army Base Colony Workshop']),
#  'Yamlur,Bellandur': set(['Town Centre, Building No 3, West Wing, Off HAL Airport Road, Yamlur,Bellandur']),
#  'Yelahanka,': set(['Jarakabande Kaval, Post Attur, Via Yelahanka,']),
#  'Yelahanka,,': set(['Jakkur Main Road,, Shivanahalli,, Yelahanka,,']),
#  'Yelenahalli,': set([', SLV Crystal Apartment, Begur-Koppa Rd, Near SNN Apartment, Yelenahalli,']),
#  'Yemalur': set(['Behind CGI Building, Chowdeshwari Temple Cross,, Yemalur']),
#  'Yemalur,': set(['Chowdeshwari Temple Cross,, Yemalur,']),
#  'Yemlur': set(['Yemlur']),
#  'Yeshwanthpur': set([',HMT Main Road, MS Ramaiah Rd, Bhadrappa Layout, Nanjappa Reddy Colony, Yeshwanthpur',
#                       "15/6/1-1,DANNIE'S AREADE, GOKULA,, 1st Stage, Gokul Extension, Divanarapalya, Yeshwanthpur",
#                       'Industrial Suburb, Yeshwanthpur, Yeshwanthpur, Yesvantpur Industrial Suburb, Yeshwanthpur',
#                       'Nanjappa Reddy Colony, 1st Main Rd, K. N. Extension, Kamla Nehru. Extension, Yeshwanthpur',
#                       'RING ROAD, Industrial Suburb - II Stage, Yeshwanthpur, Raja Industrial Estate, Yeshwanthpur']),
#  'Yeshwanthpur,': set(['80 Feet Road, Mohan Kumar Nagar, Yeshwanthpur, Mohan Kumar Nagar, Yeshwanthpur,',
#                        'Industrial Suburb, II Stage, Tumkur Road, Yeshwanthpur, Raja Industrial Estate, Yeshwanthpur,',
#                        'Near -1, Yeshwanthpur - Tumkur Railway Station Road, Yeshwanthpur Industrial Area, Phase 1, Yeshwanthpur, Yeshwanthpur Industrial Area, Phase 1, Yeshwanthpur,',
#                        'Near RNS Motor, Tumkur Road, Yeshwanthpur Industrial Area, Yeshwanthpur Industrial Area, Phase 1, Yeshwanthpur,',
#                        'Yesvantpur Industrial Suburb, Yeshwanthpur,',
#                        'yesvantpur Industrial Suburb, Yeshwanthpur,']),
#  'Zone': set(['EPIP Zone', 'Epip Zone']),
#  'Zuri)': set(['ITPL Main Road (Near Hotel Zuri)']),
#  'abc': set(['abc']),
#  'area': set(['EPIP Industrial area',
#               'Krishna nagar indl. area',
#               'Wind tunnel road, HAL airport area',
#               'flat-743,kidab  industrial estates,kadugodiu industrial area']),
#  'area,Whitefield': set(['EPIP area,Whitefield']),
#  'area,whitefield': set(['EPIP area,whitefield']),
#  'bangalore': set(['beside corporation bank, whitefield, bangalore']),
#  'bangalore-87': set(['1st cross, halasahalli road behind varthur police station,varthur bangalore-87']),
#  'banglora': set(['1st floor,linga reddy building,outer ring road,n r banglora']),
#  'banglore': set(['kariyaammana agrahara bellandur banglore']),
#  'bank': set(['HRBR Lay out, Near Axis bank']),
#  'belandur,': set(['Yemalur Main road, yemalur, belandur,']),
#  'bellandur': set(['487/4, bellandur',
#                    '7th cross road, bellandur',
#                    'Kariyammana agrahara road, kempapura, bellandur',
#                    'Kempapura Main Road, bellandur',
#                    'nal beur camous wind tunnel road ,kempapura bellandur',
#                    'rohan jharoka phase 1 kampapura bellandur',
#                    'rohan jharoka road kampapura bellandur',
#                    'swagger rd, bellandur',
#                    'yemalur main road bellandur',
#                    'yemalur, 4, kempapura main road, phase 1, kempapura bellandur']),
#  'bengaluru': set(['39/5 kariyammana agrahara village outer ring road varthur holi bengaluru',
#                    'near.new horizon college devarbisanahalli outer ring road bengaluru',
#                    'service road chandana bengaluru']),
#  'bhagini': set(['ORR  opposite bhagini']),
#  'bharathnagar': set(['4th Cross Road, jai bharathnagar']),
#  'block': set(['17th b main, 6th block',
#                '1st F Cross, 3rd stage, 4th block',
#                '4 th main 2 nd block',
#                '6th Cross,RMV 2nd stage, 2nd block',
#                'Jayanagar 3rd block',
#                'Koramangala 7th block',
#                'chowdiah block']),
#  'block,Koramangala': set(['kathalipalya village ,Ejipura Dhekale ,6th cross 6th, block,Koramangala']),
#  'block,rajajinagar': set(['53rd cross,siddaramana dinne,rajajinagar,3rd block,rajajinagar']),
#  'bridge': set(['Below bellandur ring road bridge',
#                 'D.No.791, Outer Ring Road , Marathahalli Extension, Near to Marathalli bridge']),
#  'btm': set(['14th cross btm']),
#  'campus': set(['p.o.2 jeevan jothi campus']),
#  'colony': set([', R.K complex, K.H.B colony',
#                 '2nd cross, 515 Army Base Workshop colony',
#                 'Hutting colony',
#                 'naga ahuja enclave,near naga theater,st jhon road ,ulsoor,frazer town post,hermit colony',
#                 'telecom colony',
#                 'vijaya bank colony']),
#  'compound': set(['MTB compound']),
#  'cross': set(['10th cross',
#                '11th cross',
#                '12th cross',
#                '13th A cross',
#                '13th cross',
#                '17th cross',
#                '18th cross',
#                '19th D cross',
#                '1st cross',
#                '20th cross',
#                '2nd cross',
#                '2nd main,  2nd cross',
#                '3rd cross',
#                '3rd main ,7th cross',
#                '3rd main, 7th cross',
#                '4th cross',
#                '6th cross',
#                '7th cross',
#                '8th cross',
#                '9th cross',
#                'Kor 5th cross',
#                'Koramangala 5t cross',
#                'Koramangala 5th cross',
#                'Ramaiah raju layout, outer ring road behind aswini astoriya,2nd main cross',
#                'alur cross',
#                'kodigehalli main road, 1st main, 4th cross']),
#  'cross,': set(['Ramaiah raju layout, outer ring road behind aswini astoriya,2nd main cross,']),
#  'cross,bellandur': set(['9th cross,bellandur']),
#  'cross,someshwarnagar': set(['3rd A main,4th A cross,someshwarnagar']),
#  'dattatreyanagar': set(['hosakerehalli dattatreyanagar']),
#  'devarbisanahallibanglore': set(['plotno.53 kariyammana agrahara road outer ring road,next to intel junction flyover devarbisanahallibanglore']),
#  'digital': set(['ion digital']),
#  'east': set(['Tuasi theater rd, 3rd cross, Marathalli east']),
#  'extension': set(['7th cross swimming pool extension',
#                    'Dr. Modi Hospital Road, 2nd stage extension']),
#  'extn': set(['Prashant layout extn']),
#  'farm': set(['K R road, Tata silk farm']),
#  'feet': set(['100 feet']),
#  'galli': set(['maruti galli']),
#  'gate': set(['somnahalli gate']),
#  'girinagar': set(['80 feet road girinagar']),
#  'gudahalli': set(['vinayaka nagar old gudahalli']),
#  'halasuru': set(['3rd main shridi sai baba mandir road, Cambridge layout halasuru']),
#  'halli': set(['doddakane halli']),
#  'havernce': set(['Allasandra main road , Yelahanka,Near janapriya havernce']),
#  'hobli': set(['Soul space spirit,bellandur,varthur hobli']),
#  'hotel,rajajinagar': set(['rajkumar road rajajinagar,opp.sheraton hotel,rajajinagar']),
#  'ibbalur': set(['sarjapura main road, ibbalur']),
#  'indranagar': set(['indranagar']),
#  'jayanagar': set(['jayanagar']),
#  'junction': set(['HSR layout, near Bommanahalli, silkboard junction']),
#  'kadubessanahalli': set(['basement ,b block salarpuriya touch stone it park kadubessanahalli']),
#  'kaikondrahalli': set(['Sarjapur Road, kaikondrahalli']),
#  'kampapura,bellandur': set(['kampapura,bellandur']),
#  'karnataka': set(['Panathur, Chandana, Bengaluru karnataka',
#                    'chandana.kadabeesanahalli karnataka']),
#  'kattigenahalli': set(['Behind Panchayat office,  kattigenahalli']),
#  'kik': set(['kik']),
#  'kodihalli': set(['Old airport road, kodihalli']),
#  'koramangala': set(['17th b main koramangala',
#                      '5th Cross Road koramangala',
#                      '5th cross 5th block koramangala',
#                      '6th block koramangala']),
#  'kormangala': set(['80 Feet Road kormangala']),
#  'laboratories,bellandur': set(['national aerospace laboratories,bellandur']),
#  'lake': set(['Sarjapura main road, Koramangala, , Near Agra lake']),
#  'lavelle': set(['casa lavelle']),
#  'layout': set(['12th main road , BHCS layout',
#                 '18th Cross Road, Near Reliance Digital, Sector 3, HSR layout',
#                 '27 main sector-1 Hsr layout',
#                 '27 main, sector-1, Hsr layout',
#                 '27 main, sector-1, hsr layout',
#                 '9th Main Road HSR layout',
#                 'Adhishakthi layout',
#                 'Axis Road Near domlur - indiranagar flyover domlur layout',
#                 'BTM layout',
#                 'Banaswadi layout',
#                 'HBR layout',
#                 'HRBR layout',
#                 'HSR layout',
#                 'Hrbr layout',
#                 'Hsr layout',
#                 'btm layout',
#                 'maruthi layout']),
#  'layout,bellandur': set(['Margosa Ave,green glen layout,bellandur']),
#  'layout,mathikere': set(['4th cross, hmt layout,mathikere']),
#  'local_knowledge': set(['local_knowledge']),
#  'mahadevapura': set(['mahadevapura']),
#  'mahdevpura': set(['mahdevpura']),
#  'main': set(['11th main',
#               '14th main',
#               '17th B main',
#               '1st main',
#               '24th main',
#               '27 main',
#               '27th main',
#               '28th main',
#               '2nd A main',
#               '2nd main',
#               '30th Cross 12th main',
#               '4th main',
#               '5th main',
#               '7th Cross 10th main']),
#  'main,Marathahalli': set(['Tulasitheatar road 8th main,Marathahalli']),
#  'mainroad': set(['lakshmipuram 1st mainroad']),
#  'mall,Bellandur': set(['central mall,Bellandur']),
#  'mall,bellandur': set(['2nd floor,central mall,bellandur',
#                         '2nd main road,near central mall,bellandur',
#                         'Soul & space,central mall,bellandur',
#                         'central mall,bellandur']),
#  'malleshwaram': set(['18th Cross malleshwaram']),
#  'murugeshapallya': set(['skylark residency wind tunnel road, murugeshapallya']),
#  'nagar': set(['1st Floor, 5th A cross LL Block, HRBR layout, Kalyan nagar',
#                '3rd Main Saraswathi nagar',
#                '6th Main road Indra nagar',
#                'Rajeswari nagar']),
#  'nagar,': set(['Haji layout.TCPalya Main Road, ramamurthy nagar,']),
#  'out': set(['20th main, Industrial lay out']),
#  'outerring,bellandur': set(['marthalli sarajapur outerring,bellandur']),
#  'park': set(['Cessna business park']),
#  'phase': set(['4th cross, Sai Enclave, JP Nagar 7th phase']),
#  'phase,': set(['shop no 9, wilson garden society, opp.RBI layout, kothanur main road, j.p nagar 7th phase,']),
#  'puttenahalli': set(['puttenahalli']),
#  'rajajinagar': set(['Dr rajkumar road,opp sheraton hotel rajajinagar',
#                      'rajajinagar']),
#  'raod': set(['3rd A main raod']),
#  'road': set([',Annaiahappa Building, Kadubeesanahalli, panathur main road',
#               '100 feet road',
#               '11th main road',
#               '12th main road',
#               '1st main road',
#               '3rd main road',
#               '5th main road',
#               '80 feet main road',
#               '80 feet road',
#               '9th A Main Road, First Stage, Indiranagar,, Landmark-Road next to 1st main defence colony 100feet road',
#               'Abbigere Main road',
#               'Adugodi main road',
#               'Bagalur road',
#               'Budigere cross road',
#               'Budigere road',
#               'CMH road',
#               'Commercial Complex, Rainbow Drive Layout, Doddakannelli, sarjapur road',
#               'Convent road',
#               'Hennagara Main road',
#               'Hosur road',
#               'Immidahalli road',
#               'Jeevan Bhima Nagar Main road',
#               'Jyothinivas college road',
#               'Kasavanahalli main road, sarjapur road',
#               'Kathriguppa main road',
#               'Kempegowda international airport road',
#               'Kempegowda road',
#               'Kodichikkanahalli main road',
#               'Magadi main road',
#               'Manipal County road',
#               'Modi Hospital road',
#               'Off Andhrahalli Main road',
#               'Outer ring road',
#               'Ramesh nagar road',
#               'Rangaswamy road',
#               'Sarjapur road',
#               'Sarjapura road',
#               'Sarjapure road',
#               'Shantipura Main road',
#               'Shivanahalli main road',
#               'Subbanna Garden Main road',
#               'Subbanna Garden road',
#               'Subedar Chatram road',
#               'Varthur road',
#               'Vidyanagara Cross, Kempegowda international airport road',
#               'Yallappa V road',
#               'banjarapalya main road',
#               'bannerughatta road',
#               'boganhalli road',
#               'c i l main road',
#               'chandra road',
#               'cunningham cross road',
#               'doddakannelli village,sarjapur main road',
#               'elephant cave road',
#               'goshala road',
#               'hosa road',
#               'hosur road',
#               'kammahalli road',
#               'lakshmipuram 1st main road',
#               'marthalli road',
#               'near thigalarapalya main road',
#               'patel g kullappa road',
#               'pwd road',
#               'sarjaputr road',
#               'seegehalli, whitefield road',
#               'sjp road',
#               'somasundarapalaya road',
#               'swagger road',
#               'temple street road',
#               'thubarahalli extended road',
#               'yemalur camous ,opp sai garden apartments kempapuram main road']),
#  'road)': set(['Indiranagar Double Road (Paramahansa Yogananda road)']),
#  'road,': set(['Jeevan Bhima Nagar Main road,',
#                'Kaikondrahalli,Sarjapur main road,',
#                'Near New Horizon College, Devarabisanahalli,  Outer Ring road,',
#                'Near New Horizon College, Devarabisanahalli, Outer Ring road,']),
#  'road,Seetharampalya': set(['Graphite India road,Seetharampalya']),
#  'road,banashankari': set(['80 feet road,banashankari']),
#  'road,bellandur': set(['devarai besanahali main road,bellandur',
#                         'kariyammana agrahara road,bellandur',
#                         'temple road,bellandur',
#                         'wind tunnel road,bellandur',
#                         'yemallur road,bellandur']),
#  'road,kempapur,bellandur': set(['yemlur road,kempapur,bellandur']),
#  'road,kempapura,bellandur': set(['kempapura main road,kempapura,bellandur',
#                                   'rohan jharoka road,kempapura,bellandur']),
#  'road,kempapura,bellandur,': set(['kempapura main road,kempapura,bellandur,']),
#  'school': set(['No, Santhe road , Yelahanka Opp to cambridge school']),
#  'sector': set(['22nd cross, hsr 2nd sector',
#                 '24th Main,HSR 2nd sector',
#                 '24th main hsr 2nd sector']),
#  'seegehalli': set(['seegehalli']),
#  'singasandra,hsrlayout': set(['hosur main road,7th mile, singasandra,hsrlayout']),
#  'stage': set(['1st C cross, 2nd phase 4th block, BSK 3rd stage',
#                '2nd cross domlur 2nd stage']),
#  'street': set(['Church street',
#                 'car street',
#                 'jnguva street',
#                 'temple street']),
#  'sultanpet,': set(['P.o box 7182,1st floor, sultanpet,']),
#  'temple': set(['narashima samy temple']),
#  'temple,yemallur': set(['vinayaka furits & vegitables, near ganapathi temple,yemallur']),
#  'vijayanagar': set(['vijayanagar']),
#  'village': set(['Bettahalasur village',
#                  'Opp. Durga Residency, 5th Main Road,Ibblur village',
#                  'Outer ring road, Bellandur village']),
#  'whitefield': set(['EPIP  area whitefield']),
#  'wipro': set(['Electronics City Phase 1, Electronics City,near wipro']),
#  'woods,bellandur': set(['behind new vengopala swamy temple opposite sonesta woods,bellandur']),
#  'yemallure,bellandur': set(['yemallure,bellandur'])}

# %%
from collections import defaultdict

def audit_zipcode(invalid_zipcodes, zipcode):
    threeDigits = zipcode[0:3]
    
    if not threeDigits.isdigit():
        invalid_zipcodes[threeDigits].add(zipcode)
    
    elif threeDigits != 560:
        invalid_zipcodes[threeDigits].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

cal_zipcode = audit_zip(cal_data)

# %%
pprint.pprint(dict(cal_zipcode))
# Out:
# {'- 5': set(['- 560001',
#              '- 560011',
#              '- 560027',
#              '- 560034',
#              '- 560051',
#              '- 560068',
#              '- 560076',
#              '- 560094,',
#              '- 560095']),
#  '380': set(['380068']),
#  '500': set(['500006', '500036', '500076']),
#  '530': set(['530078', '530103']),
#  '540': set(['540045']),
#  '556': set(['5560034']),
#  '560': set(['560 001',
#              '560 002',
#              '560 020',
#              '560 025',
#              '560 036',
#              '560 037',
#              '560 048',
#              '560 052',
#              '560 055',
#              '560 064',
#              '560 068',
#              '560 077',
#              '560 078',
#              '560 080',
#              '560 090',
#              '560 091',
#              '560 100',
#              '5600',
#              '560001',
#              '5600011',
#              '560001ph',
#              '560002',
#              '560003',
#              '560003 ',
#              '5600037',
#              '560004',
#              '5600041',
#              '5600043',
#              '560005',
#              '560007',
#              '560008',
#              '560008,',
#              '560009',
#              '5600091',
#              '560010',
#              '560010,',
#              '5600109',
#              '560011',
#              '560012',
#              '560013',
#              '560016',
#              '560017',
#              '560018',
#              '560019',
#              '560020',
#              '560021',
#              '560022',
#              '560023',
#              '560024',
#              '560025',
#              '560026',
#              '560027',
#              '560027"',
#              '560028',
#              '560029',
#              '560029 ',
#              '56003',
#              '560030',
#              '560032',
#              '560032,',
#              '560033',
#              '560034',
#              '560035',
#              '560036',
#              '560037',
#              '560038',
#              '560039',
#              '560040',
#              '560040p',
#              '560041',
#              '560042',
#              '560043',
#              '560043,',
#              '560045',
#              '560046',
#              '560047',
#              '560048',
#              '560049',
#              '56005',
#              '560050',
#              '560051',
#              '560052',
#              '560053',
#              '560054',
#              '560055',
#              '560056',
#              '560057',
#              '560058',
#              '560059',
#              '56006',
#              '560060',
#              '560061',
#              '560062',
#              '560063',
#              '560064',
#              '560065',
#              '560066',
#              '560067',
#              '560067,',
#              '560068',
#              '560068,',
#              '560069',
#              '56007',
#              '560070',
#              '560070"',
#              '560071',
#              '560072',
#              '560072,',
#              '560073',
#              '560074',
#              '560075',
#              '560075,',
#              '560076',
#              '560076,',
#              '560077',
#              '560078',
#              '560079',
#              '560080',
#              '560080"',
#              '560082',
#              '560083',
#              '560084',
#              '560085',
#              '560086',
#              '560086,',
#              '560087',
#              '560090',
#              '560091',
#              '560092',
#              '560093',
#              '560094',
#              '560095',
#              '560097',
#              '560098',
#              '560099',
#              '560100',
#              '560100"',
#              '560100,',
#              '5601003',
#              '560102',
#              '560103',
#              '560104',
#              '560105',
#              '560106',
#              '560110',
#              '560111',
#              '560300',
#              '56066',
#              '56077',
#              '56085']),
#  '561': set(['561203']),
#  '562': set(['562106',
#              '562107',
#              '562112',
#              '562114',
#              '562117',
#              '562123',
#              '562125',
#              '562134',
#              '562157',
#              '562159',
#              '562162']),
#  '570': set(['570008']),
#  '571': set(['571438']),
#  '583': set(['583105']),
#  '600': set(['600042']),
#  '635': set(['635109', '635126']),
#  '650': set(['650027']),
#  '79': set(['79']),
#  'Ben': set(['Bengaluru']),
#  'iam': set(['iam in bang']),
#  u'\u0ceb\u0cec\u0ce6': set([u'\u0ceb\u0cec\u0ce6\u0ce6\u0cec\u0ce6'])}

# %%
def update_name(zipcode):
    testNum = re.findall('[a-zA-Z]*', zipcode)
    if testNum:
        testNum = testNum[0]
    testNum.strip()
    if testNum == "- ":
        convertedZipcode = (re.findall(r'\d+', zipcode))
        if convertedZipcode:
            if convertedZipcode.__len__() ==2:
                return (re.findall(r'\d+', zipcode))[0] + "-" +(re.findall(r'\d+', zipcode))[1]
            else:
                return (re.findall(r'\d+', zipcode))[0]

for street_type, ways in cal_zipcode.iteritems():
    for name in ways:
        better_name = update_name(name)
        print name, "=>", better_name
# Out:
# iam in bang => None
# ೫೬೦೦೬೦ => None
# - 560034 => None
# - 560068 => None
# - 560051 => None
# - 560011 => None
# - 560076 => None
# - 560094, => None
# - 560001 => None
# - 560095 => None
# - 560027 => None
# Bengaluru => None
# 635126 => None
# 635109 => None
# 560067, => None
# 560 001 => None
# 560 002 => None
# 560087 => None
# 560086 => None
# 560085 => None
# 560084 => None
# 560083 => None
# 560082 => None
# 560080 => None
# 560 080 => None
# 560069 => None
# 5601003 => None
# 560086, => None
# 560100" => None
# 560009 => None
# 560008 => None
# 560007 => None
# 560027" => None
# 560005 => None
# 560004 => None
# 560003 => None
# 560002 => None
# 560001 => None
# 560 078 => None
# 56066 => None
# 560 037 => None
# 560 036 => None
# 560070" => None
# 560080" => None
# 56085 => None
# 560078 => None
# 560079 => None
# 560072 => None
# 560073 => None
# 560070 => None
# 560071 => None
# 560076 => None
# 560077 => None
# 560074 => None
# 560075 => None
# 560 100 => None
# 56007 => None
# 56005 => None
# 5600 => None
# 5600011 => None
# 560076, => None
# 56077 => None
# 5600091 => None
# 560106 => None
# 560068 => None
# 560104 => None
# 560105 => None
# 560102 => None
# 560103 => None
# 560100 => None
# 560061 => None
# 560060 => None
# 560063 => None
# 560062 => None
# 560065 => None
# 560064 => None
# 560067 => None
# 560066 => None
# 560072, => None
# 560040p => None
# 560043, => None
# 560054 => None
# 560055 => None
# 560056 => None
# 560057 => None
# 560050 => None
# 560051 => None
# 560052 => None
# 560053 => None
# 560001ph => None
# 560058 => None
# 560059 => None
# 560 025 => None
# 560111 => None
# 560110 => None
# 560 020 => None
# 560008, => None
# 560032, => None
# 560003  => None
# 5600037 => None
# 560043 => None
# 560042 => None
# 560041 => None
# 560040 => None
# 560047 => None
# 560046 => None
# 560045 => None
# 560049 => None
# 560048 => None
# 560 052 => None
# 560 055 => None
# 560010, => None
# 5600109 => None
# 560100, => None
# 560036 => None
# 560037 => None
# 560034 => None
# 560035 => None
# 560032 => None
# 560033 => None
# 560030 => None
# 560 048 => None
# 560038 => None
# 560039 => None
# 560075, => None
# 560029  => None
# 560300 => None
# 560012 => None
# 560025 => None
# 560024 => None
# 560027 => None
# 560026 => None
# 560021 => None
# 560020 => None
# 560023 => None
# 560022 => None
# 560 077 => None
# 560029 => None
# 560028 => None
# 56006 => None
# 5600041 => None
# 5600043 => None
# 56003 => None
# 560068, => None
# 560 091 => None
# 560 090 => None
# 560098 => None
# 560099 => None
# 560090 => None
# 560091 => None
# 560092 => None
# 560093 => None
# 560094 => None
# 560095 => None
# 560097 => None
# 560010 => None
# 560011 => None
# 560 068 => None
# 560013 => None
# 560016 => None
# 560017 => None
# 560018 => None
# 560019 => None
# 560 064 => None
# 561203 => None
# 562162 => None
# 562157 => None
# 562123 => None
# 562134 => None
# 562125 => None
# 562112 => None
# 562106 => None
# 562107 => None
# 562117 => None
# 562159 => None
# 562114 => None
# 570008 => None
# 380068 => None
# 540045 => None
# 500036 => None
# 500076 => None
# 500006 => None
# 650027 => None
# 530103 => None
# 530078 => None
# 600042 => None
# 5560034 => None
# 571438 => None
# 79 => None
# 583105 => None

# %%
import re
import codecs
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
address_regex = re.compile(r'^addr\:')
street_regex = re.compile(r'^street')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        node['type'] = element.tag
        # initialize empty address
        address = {}
        # parsing through attributes
        for a in element.attrib:
            if a in CREATED:
                if 'created' not in node:
                    node['created'] = {}
                node['created'][a] = element.get(a)
            elif a in ['lat', 'lon']:
                continue
            else:
                node[a] = element.get(a)
        # populate position
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]

        # parse second-level tags for nodes
        for e in element:
            # parse second-level tags for ways and populate `node_refs`
            if e.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in e.attrib:
                    node['node_refs'].append(e.get('ref'))

            # throw out not-tag elements and elements without `k` or `v`
            if e.tag != 'tag' or 'k' not in e.attrib or 'v' not in e.attrib:
                continue
            key = e.get('k')
            val = e.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # parse address k-v pairs
            elif address_regex.search(key):
                key = key.replace('addr:', '')
                address[key] = val

            # catch-all
            else:
                node[key] = val
        # compile address
        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']
            # parse through address objects
            for key in address:
                val = address[key]
                if street_regex.search(key):
                    if key == 'street':
                        street_full = val
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val
            # assign street_full or fallback to compile street dict
            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                node['address']['street'] = ' '.join([street_dict[key] for key in street_format])
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data
process_map(cal_data)
# Out:
# [{'created': {'changeset': '16957521',
#    'timestamp': '2013-07-15T08:10:50Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '4'},
#   'id': '17327077',
#   'pos': [12.9026964, 77.5949117],
#   'type': 'node'},
#  {'created': {'changeset': '18611831',
#    'timestamp': '2013-10-30T05:16:40Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '32'},
#   'id': '17327092',
#   'pos': [12.9063367, 77.5950592],
#   'type': 'node'},
#  {'created': {'changeset': '18598983',
#    'timestamp': '2013-10-29T11:01:32Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '32'},
#   'id': '17327095',
#   'pos': [12.910516, 77.5987265],
#   'type': 'node'},
#  {'created': {'changeset': '44678289',
#    'timestamp': '2016-12-26T09:39:52Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '75'},
#   'highway': 'traffic_signals',
#   'id': '17327106',
#   'name': 'Aurobindo Circle',
#   'name:kn': u'\u0c85\u0cb0\u0cb5\u0cbf\u0c82\u0ca6 \u0cb5\u0cc3\u0ca4\u0ccd\u0ca4',
#   'pos': [12.9171587, 77.5858225],
#   'type': 'node'},
#  {'created': {'changeset': '833006',
#    'timestamp': '2009-03-19T17:09:30Z',
#    'uid': '35811',
#    'user': 'Praveen',
#    'version': '29'},
#   'id': '17327139',
#   'pos': [12.9349712, 77.624083],
#   'type': 'node'},
#  {'created': {'changeset': '8054691',
#    'timestamp': '2011-05-05T06:28:55Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '21'},
#   'id': '17327141',
#   'pos': [12.9384996, 77.62914],
#   'type': 'node'},
#  {'created': {'changeset': '40811202',
#    'timestamp': '2016-07-18T06:17:05Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '21'},
#   'id': '17327147',
#   'pos': [12.9542527, 77.6412143],
#   'type': 'node'},
#  {'created': {'changeset': '17785748',
#    'timestamp': '2013-09-11T16:39:56Z',
#    'uid': '1319316',
#    'user': 'Gururaja Upadhyaya',
#    'version': '10'},
#   'highway': 'bus_stop',
#   'id': '17327417',
#   'local_ref': 'YELAHANKA',
#   'name': 'Escorts Yalahanka Road',
#   'pos': [13.1023158, 77.5860665],
#   'type': 'node'},
#  {'created': {'changeset': '17796766',
#    'timestamp': '2013-09-12T10:15:59Z',
#    'uid': '1319316',
#    'user': 'Gururaja Upadhyaya',
#    'version': '13'},
#   'id': '17327420',
#   'pos': [13.0953189, 77.594113],
#   'type': 'node'},
#  {'created': {'changeset': '13687114',
#    'timestamp': '2012-10-30T14:02:56Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '4'},
#   'id': '17327429',
#   'pos': [12.993304, 77.583961],
#   'type': 'node'},
#  {'created': {'changeset': '10774531',
#    'timestamp': '2012-02-24T03:18:15Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '3'},
#   'id': '17327433',
#   'pos': [12.9859788, 77.5792942],
#   'type': 'node'},
#  {'created': {'changeset': '26587371',
#    'timestamp': '2014-11-06T07:56:32Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '34'},
#   'id': '26529519',
#   'pos': [12.9728616, 77.6199745],
#   'type': 'node'},
#  {'created': {'changeset': '36923602',
#    'timestamp': '2016-01-31T19:21:38Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'highway': 'traffic_signals',
#   'id': '26529522',
#   'pos': [12.9747225, 77.6200056],
#   'type': 'node'},
#  {'created': {'changeset': '11157251',
#    'timestamp': '2012-03-30T16:48:20Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '6'},
#   'id': '26529524',
#   'pos': [12.9756821, 77.6202334],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529527',
#   'pos': [12.977516, 77.6202505],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529529',
#   'pos': [12.9777544, 77.6202616],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529530',
#   'pos': [12.9781844, 77.6203816],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529532',
#   'pos': [12.9785543, 77.6205594],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529533',
#   'pos': [12.9787415, 77.6207572],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529540',
#   'pos': [12.9790607, 77.6214838],
#   'type': 'node'},
#  {'created': {'changeset': '13194341',
#    'timestamp': '2012-09-21T11:46:57Z',
#    'uid': '697874',
#    'user': 'Sandeep Nayak',
#    'version': '5'},
#   'id': '26529541',
#   'pos': [12.9792653, 77.6216327],
#   'type': 'node'},
#  {'created': {'changeset': '13194341',
#    'timestamp': '2012-09-21T11:46:57Z',
#    'uid': '697874',
#    'user': 'Sandeep Nayak',
#    'version': '5'},
#   'id': '26529543',
#   'pos': [12.9795879, 77.6217622],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529548',
#   'pos': [12.9809441, 77.6223667],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '26529550',
#   'pos': [12.9811382, 77.6225525],
#   'type': 'node'},
#  {'created': {'changeset': '28328106',
#    'timestamp': '2015-01-22T13:52:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '26529551',
#   'pos': [12.9812828, 77.6227574],
#   'type': 'node'},
#  {'created': {'changeset': '41382822',
#    'timestamp': '2016-08-11T07:41:28Z',
#    'uid': '2905914',
#    'user': 'pratikyadav',
#    'version': '11'},
#   'crossing': 'traffic_signals',
#   'highway': 'traffic_signals',
#   'id': '26529553',
#   'pos': [12.9815241, 77.6230894],
#   'type': 'node'},
#  {'created': {'changeset': '11157251',
#    'timestamp': '2012-03-30T16:48:20Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '3'},
#   'id': '26529555',
#   'pos': [12.9818405, 77.6228721],
#   'type': 'node'},
#  {'created': {'changeset': '48553475',
#    'timestamp': '2017-05-10T07:26:42Z',
#    'uid': '2905914',
#    'user': 'pratikyadav',
#    'version': '2'},
#   'id': '26529561',
#   'pos': [12.9835805, 77.6224771],
#   'type': 'node'},
#  {'created': {'changeset': '48553475',
#    'timestamp': '2017-05-10T07:26:42Z',
#    'uid': '2905914',
#    'user': 'pratikyadav',
#    'version': '2'},
#   'id': '26529563',
#   'pos': [12.9841518, 77.6223995],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:52:02Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529567',
#   'pos': [12.9853617, 77.6224175],
#   'type': 'node'},
#  {'created': {'changeset': '1702034',
#    'timestamp': '2009-07-01T17:11:31Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529574',
#   'pos': [12.9871884, 77.6225171],
#   'type': 'node'},
#  {'created': {'changeset': '39834028',
#    'timestamp': '2016-06-06T09:28:13Z',
#    'uid': '2905914',
#    'user': 'pratikyadav',
#    'version': '6'},
#   'id': '26529577',
#   'pos': [12.9876878, 77.6224421],
#   'type': 'node'},
#  {'created': {'changeset': '39832355',
#    'timestamp': '2016-06-06T07:56:57Z',
#    'uid': '2905914',
#    'user': 'pratikyadav',
#    'version': '5'},
#   'id': '26529581',
#   'pos': [12.9874416, 77.6203354],
#   'type': 'node'},
#  {'created': {'changeset': '1740871',
#    'timestamp': '2009-07-05T16:58:24Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '14'},
#   'id': '26529582',
#   'pos': [12.9871566, 77.6199311],
#   'type': 'node'},
#  {'created': {'changeset': '9944706',
#    'timestamp': '2011-11-25T14:34:23Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '12'},
#   'id': '26529584',
#   'pos': [12.9863647, 77.6194617],
#   'type': 'node'},
#  {'created': {'changeset': '12543709',
#    'timestamp': '2012-07-30T06:41:38Z',
#    'uid': '697960',
#    'user': 'vkvora',
#    'version': '10'},
#   'id': '26529589',
#   'pos': [12.9814677, 77.615623],
#   'type': 'node'},
#  {'created': {'changeset': '12543709',
#    'timestamp': '2012-07-30T06:41:38Z',
#    'uid': '697960',
#    'user': 'vkvora',
#    'version': '4'},
#   'id': '26529594',
#   'pos': [12.9805282, 77.6167291],
#   'type': 'node'},
#  {'created': {'changeset': '4703536',
#    'timestamp': '2010-05-15T08:01:30Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529600',
#   'pos': [12.9801694, 77.6176429],
#   'type': 'node'},
#  {'created': {'changeset': '4703536',
#    'timestamp': '2010-05-15T08:01:33Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529602',
#   'pos': [12.9799479, 77.6178704],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:35Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529603',
#   'pos': [12.9794645, 77.6181656],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:35Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529605',
#   'pos': [12.9788773, 77.6185105],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:35Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529606',
#   'pos': [12.9780945, 77.6189046],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:35Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529608',
#   'pos': [12.9774298, 77.6192608],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:35Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529612',
#   'pos': [12.9770827, 77.6198633],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529613',
#   'pos': [12.9772673, 77.6198595],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529615',
#   'pos': [12.9775369, 77.6198141],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529616',
#   'pos': [12.9780169, 77.619617],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529620',
#   'pos': [12.9799593, 77.6183513],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529621',
#   'pos': [12.9804504, 77.618033],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529622',
#   'pos': [12.9807126, 77.6177677],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529623',
#   'pos': [12.9808566, 77.6175138],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529624',
#   'pos': [12.9809453, 77.6171083],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:36Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529625',
#   'pos': [12.981045, 77.616646],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:37Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529626',
#   'pos': [12.9811114, 77.6164414],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:37Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529627',
#   'pos': [12.9811742, 77.6162898],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:37Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529628',
#   'pos': [12.9813588, 77.6161155],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529629',
#   'pos': [12.9814855, 77.616058],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529630',
#   'pos': [12.9817024, 77.6158354],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529631',
#   'pos': [12.9819167, 77.6157817],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:37Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529634',
#   'pos': [12.9826476, 77.6159828],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529635',
#   'pos': [12.9827583, 77.6160178],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529636',
#   'pos': [12.9828995, 77.6161411],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529637',
#   'pos': [12.9832262, 77.6167473],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529638',
#   'pos': [12.9834718, 77.6171389],
#   'type': 'node'},
#  {'created': {'changeset': '28394049',
#    'timestamp': '2015-01-25T12:24:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26529639',
#   'pos': [12.9835424, 77.6172677],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:38Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529640',
#   'pos': [12.9845641, 77.61823],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:38Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529641',
#   'pos': [12.9850958, 77.6187454],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:38Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529642',
#   'pos': [12.9855168, 77.6191244],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:38Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529643',
#   'pos': [12.9861224, 77.6194957],
#   'type': 'node'},
#  {'created': {'changeset': '235985',
#    'timestamp': '2007-03-14T13:56:38Z',
#    'uid': '2179',
#    'user': 'Scooter_DE',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '26529644',
#   'pos': [12.9864362, 77.619689],
#   'type': 'node'},
#  {'created': {'changeset': '26587371',
#    'timestamp': '2014-11-06T07:56:31Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '9'},
#   'id': '26529645',
#   'pos': [12.9727374, 77.6202548],
#   'type': 'node'},
#  {'created': {'changeset': '7767885',
#    'timestamp': '2011-04-04T20:56:11Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '17'},
#   'id': '26529654',
#   'pos': [12.9726672, 77.6187063],
#   'type': 'node'},
#  {'created': {'changeset': '28861438',
#    'timestamp': '2015-02-15T12:06:26Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '20'},
#   'id': '26529655',
#   'pos': [12.9726312, 77.6191886],
#   'type': 'node'},
#  {'created': {'changeset': '7707329',
#    'timestamp': '2011-03-29T14:34:32Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '26583024',
#   'pos': [12.9488058, 77.6541221],
#   'type': 'node'},
#  {'created': {'changeset': '9601428',
#    'timestamp': '2011-10-19T16:54:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '26583025',
#   'pos': [12.9492724, 77.6593306],
#   'type': 'node'},
#  {'created': {'changeset': '9601428',
#    'timestamp': '2011-10-19T16:54:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '26583026',
#   'pos': [12.9504419, 77.6723849],
#   'type': 'node'},
#  {'created': {'changeset': '12623815',
#    'timestamp': '2012-08-05T17:41:10Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '2'},
#   'id': '26583027',
#   'pos': [12.9515215, 77.6843349],
#   'type': 'node'},
#  {'created': {'changeset': '43326007',
#    'timestamp': '2016-11-01T13:30:20Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '11'},
#   'id': '26609019',
#   'pos': [12.9480513, 77.6707926],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:39Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '12'},
#   'highway': 'traffic_signals',
#   'id': '60952254',
#   'junction': 'yes',
#   'name': 'Prof Ashirvadam Junction',
#   'pos': [12.970884, 77.6047644],
#   'type': 'node'},
#  {'created': {'changeset': '28780304',
#    'timestamp': '2015-02-11T19:16:14Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '16'},
#   'id': '60952256',
#   'pos': [12.9736793, 77.6105912],
#   'type': 'node'},
#  {'alt_name': 'Vellara Junction',
#   'created': {'changeset': '44358792',
#    'timestamp': '2016-12-12T21:32:18Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '24'},
#   'highway': 'traffic_signals',
#   'id': '60952260',
#   'junction': 'yes',
#   'name': 'Shoolay Circle',
#   'name:kn': u'\u0cb6\u0cc2\u0cb2\u0cc6 \u0cb5\u0cc3\u0ca4\u0ccd\u0ca4',
#   'pos': [12.9662604, 77.6067163],
#   'type': 'node'},
#  {'created': {'changeset': '6890076',
#    'timestamp': '2011-01-07T08:15:25Z',
#    'uid': '392516',
#    'user': 'venkatesh-Elintsys',
#    'version': '8'},
#   'id': '60952264',
#   'pos': [12.9698611, 77.6029825],
#   'type': 'node'},
#  {'created': {'changeset': '6890076',
#    'timestamp': '2011-01-07T08:15:24Z',
#    'uid': '392516',
#    'user': 'venkatesh-Elintsys',
#    'version': '10'},
#   'id': '60952268',
#   'pos': [12.9663767, 77.5984039],
#   'type': 'node'},
#  {'created': {'changeset': '31274949',
#    'timestamp': '2015-05-19T06:59:30Z',
#    'uid': '2901517',
#    'user': 'subhashini',
#    'version': '6'},
#   'id': '60952284',
#   'pos': [12.9659284, 77.6049397],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:43Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '12'},
#   'id': '60952286',
#   'pos': [12.9628455, 77.6066907],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:43Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '14'},
#   'crossing': 'traffic_signals',
#   'highway': 'traffic_signals',
#   'id': '60952288',
#   'pos': [12.9580248, 77.6059822],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:30Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '60952290',
#   'pos': [12.9585854, 77.604602],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:35Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '60952292',
#   'pos': [12.959392, 77.6035411],
#   'type': 'node'},
#  {'created': {'changeset': '20826266',
#    'timestamp': '2014-02-28T12:32:45Z',
#    'uid': '83660',
#    'user': 'Ashish Vijayaram',
#    'version': '6'},
#   'highway': 'traffic_signals',
#   'id': '60952294',
#   'pos': [12.9599445, 77.6018839],
#   'type': 'node'},
#  {'created': {'changeset': '18061403',
#    'timestamp': '2013-09-27T13:06:47Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '6'},
#   'id': '60952298',
#   'pos': [12.9583662, 77.602182],
#   'type': 'node'},
#  {'created': {'changeset': '28355018',
#    'timestamp': '2015-01-23T17:38:50Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '60952300',
#   'pos': [12.9559538, 77.6013684],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:44Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '15'},
#   'id': '60952302',
#   'pos': [12.9548955, 77.6053905],
#   'type': 'node'},
#  {'created': {'changeset': '28917291',
#    'timestamp': '2015-02-17T19:38:01Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '60952479',
#   'pos': [12.9705497, 77.6102757],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '19'},
#   'id': '61746200',
#   'pos': [12.9398915, 77.6254372],
#   'type': 'node'},
#  {'created': {'changeset': '16365718',
#    'timestamp': '2013-05-31T14:03:43Z',
#    'uid': '642345',
#    'user': 'Krishnan Dasan',
#    'version': '4'},
#   'id': '61746203',
#   'pos': [12.9409155, 77.6276761],
#   'type': 'node'},
#  {'created': {'changeset': '16361202',
#    'timestamp': '2013-05-31T07:30:36Z',
#    'uid': '642345',
#    'user': 'Krishnan Dasan',
#    'version': '2'},
#   'id': '61746204',
#   'pos': [12.9403319, 77.6277554],
#   'type': 'node'},
#  {'created': {'changeset': '16361202',
#    'timestamp': '2013-05-31T07:30:36Z',
#    'uid': '642345',
#    'user': 'Krishnan Dasan',
#    'version': '3'},
#   'id': '61746206',
#   'pos': [12.9404292, 77.6283275],
#   'type': 'node'},
#  {'created': {'changeset': '16361202',
#    'timestamp': '2013-05-31T07:30:36Z',
#    'uid': '642345',
#    'user': 'Krishnan Dasan',
#    'version': '5'},
#   'id': '61746207',
#   'pos': [12.9401373, 77.6283788],
#   'type': 'node'},
#  {'created': {'changeset': '16361202',
#    'timestamp': '2013-05-31T07:30:36Z',
#    'uid': '642345',
#    'user': 'Krishnan Dasan',
#    'version': '4'},
#   'id': '61746209',
#   'pos': [12.9401794, 77.6286864],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '38'},
#   'highway': 'traffic_signals',
#   'id': '61746217',
#   'pos': [12.9425358, 77.6227616],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '23'},
#   'id': '61746218',
#   'pos': [12.9460158, 77.6186488],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '24'},
#   'id': '61746220',
#   'pos': [12.9412231, 77.6241693],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '14'},
#   'id': '61746221',
#   'pos': [12.944154, 77.620952],
#   'type': 'node'},
#  {'created': {'changeset': '18044654',
#    'timestamp': '2013-09-26T14:03:50Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '10'},
#   'id': '61746695',
#   'pos': [12.9400082, 77.6092904],
#   'type': 'node'},
#  {'created': {'changeset': '18044654',
#    'timestamp': '2013-09-26T14:03:50Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '11'},
#   'id': '61746702',
#   'pos': [12.9462257, 77.6069002],
#   'type': 'node'},
#  {'created': {'changeset': '37649970',
#    'timestamp': '2016-03-06T17:49:38Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '28'},
#   'highway': 'traffic_signals',
#   'id': '61748543',
#   'pos': [12.9684273, 77.6143093],
#   'type': 'node'},
#  {'created': {'changeset': '247588',
#    'timestamp': '2008-12-07T03:58:35Z',
#    'uid': '74061',
#    'user': 'SrikanthLogic',
#    'version': '5'},
#   'id': '61748551',
#   'pos': [12.9589487, 77.6203902],
#   'type': 'node'},
#  {'created': {'changeset': '37640190',
#    'timestamp': '2016-03-06T07:36:49Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '61748552',
#   'pos': [12.9579582, 77.6211034],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'highway': 'traffic_signals',
#   'id': '61748553',
#   'pos': [12.952415, 77.6202156],
#   'type': 'node'},
#  {'created': {'changeset': '33994798',
#    'timestamp': '2015-09-13T08:26:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'highway': 'traffic_signals',
#   'id': '61748555',
#   'pos': [12.9516788, 77.6214774],
#   'type': 'node'},
#  {'created': {'changeset': '8308772',
#    'timestamp': '2011-06-01T10:28:26Z',
#    'uid': '354670',
#    'user': 'janvpi',
#    'version': '4'},
#   'id': '61748559',
#   'pos': [12.9622547, 77.5959411],
#   'type': 'node'},
#  {'created': {'changeset': '28917291',
#    'timestamp': '2015-02-17T19:38:01Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '11'},
#   'id': '62011472',
#   'pos': [12.9694383, 77.6104893],
#   'type': 'node'},
#  {'created': {'changeset': '8065558',
#    'timestamp': '2011-05-06T13:58:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '12'},
#   'id': '62011481',
#   'pos': [12.9731434, 77.6094286],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:39Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '62013201',
#   'pos': [12.9625567, 77.590491],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:41Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '62013206',
#   'pos': [12.9625615, 77.5907477],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:43Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '12'},
#   'id': '62013225',
#   'pos': [12.9615547, 77.6065708],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:43Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '10'},
#   'id': '62013229',
#   'pos': [12.9597384, 77.606223],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:43Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '13'},
#   'id': '62013232',
#   'pos': [12.9563737, 77.6057299],
#   'type': 'node'},
#  {'created': {'changeset': '38444058',
#    'timestamp': '2016-04-10T07:18:57Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '7'},
#   'id': '62053447',
#   'pos': [12.9706127, 77.5068443],
#   'type': 'node'},
#  {'created': {'changeset': '31252655',
#    'timestamp': '2015-05-18T11:48:13Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '2'},
#   'id': '62053450',
#   'pos': [12.9705309, 77.50727],
#   'type': 'node'},
#  {'created': {'changeset': '31252655',
#    'timestamp': '2015-05-18T11:48:13Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '4'},
#   'id': '62053453',
#   'pos': [12.9705056, 77.5073453],
#   'type': 'node'},
#  {'created': {'changeset': '15499371',
#    'timestamp': '2013-03-26T06:12:57Z',
#    'uid': '1296080',
#    'user': 'RSakthivel',
#    'version': '3'},
#   'id': '62053457',
#   'pos': [12.9698043, 77.5071661],
#   'type': 'node'},
#  {'created': {'changeset': '17486273',
#    'timestamp': '2013-08-24T16:01:35Z',
#    'uid': '1319316',
#    'user': 'Gururaja Upadhyaya',
#    'version': '2'},
#   'id': '62053464',
#   'pos': [12.969712, 77.5072719],
#   'type': 'node'},
#  {'created': {'changeset': '17486273',
#    'timestamp': '2013-08-24T16:01:35Z',
#    'uid': '1319316',
#    'user': 'Gururaja Upadhyaya',
#    'version': '2'},
#   'id': '62053468',
#   'pos': [12.969643, 77.5075651],
#   'type': 'node'},
#  {'created': {'changeset': '31333606',
#    'timestamp': '2015-05-21T05:41:51Z',
#    'uid': '2901820',
#    'user': 'udaykanth',
#    'version': '2'},
#   'id': '62053473',
#   'pos': [12.9694899, 77.5081646],
#   'type': 'node'},
#  {'created': {'changeset': '31333606',
#    'timestamp': '2015-05-21T05:41:51Z',
#    'uid': '2901820',
#    'user': 'udaykanth',
#    'version': '2'},
#   'id': '62053477',
#   'pos': [12.9693489, 77.5087625],
#   'type': 'node'},
#  {'created': {'changeset': '13982558',
#    'timestamp': '2012-11-22T09:16:37Z',
#    'uid': '697874',
#    'user': 'Sandeep Nayak',
#    'version': '3'},
#   'id': '62053482',
#   'pos': [12.970034, 77.5090988],
#   'type': 'node'},
#  {'created': {'changeset': '13982558',
#    'timestamp': '2012-11-22T09:16:37Z',
#    'uid': '697874',
#    'user': 'Sandeep Nayak',
#    'version': '2'},
#   'id': '62053486',
#   'pos': [12.9707297, 77.5087595],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:42Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '6'},
#   'id': '62053496',
#   'pos': [12.9717297, 77.5076555],
#   'type': 'node'},
#  {'created': {'changeset': '47864147',
#    'timestamp': '2017-04-17T09:40:54Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '12'},
#   'id': '62053503',
#   'pos': [12.960517, 77.5043062],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:58Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053522',
#   'pos': [12.962701, 77.5048941],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '6'},
#   'id': '62053528',
#   'pos': [12.9634992, 77.5050401],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '6'},
#   'id': '62053530',
#   'pos': [12.963803, 77.5050048],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:58Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053537',
#   'pos': [12.9644287, 77.5048448],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:58Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053542',
#   'pos': [12.9649363, 77.5048087],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '6'},
#   'id': '62053546',
#   'pos': [12.9657035, 77.5048267],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '7'},
#   'id': '62053550',
#   'pos': [12.9663846, 77.5049412],
#   'type': 'node'},
#  {'created': {'changeset': '38444058',
#    'timestamp': '2016-04-10T07:18:57Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '7'},
#   'id': '62053568',
#   'pos': [12.9682861, 77.5057771],
#   'type': 'node'},
#  {'created': {'changeset': '38444058',
#    'timestamp': '2016-04-10T07:18:57Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '6'},
#   'id': '62053580',
#   'pos': [12.970288, 77.5066363],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:59Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053583',
#   'pos': [12.9706305, 77.5068078],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:59Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053584',
#   'pos': [12.9711574, 77.5071157],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:59Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053597',
#   'pos': [12.9719007, 77.507657],
#   'type': 'node'},
#  {'created': {'changeset': '30092428',
#    'timestamp': '2015-04-09T12:03:44Z',
#    'uid': '827808',
#    'user': 'yogi_ks',
#    'version': '7'},
#   'highway': 'bus_stop',
#   'id': '62053599',
#   'name': 'Papareddy Palya',
#   'name:kn': u'\u0caa\u0cbe\u0caa\u0cb0\u0cc6\u0ca1\u0ccd\u0ca1\u0cbf \u0caa\u0cbe\u0cb3\u0ccd\u0caf',
#   'pos': [12.972353, 77.5079385],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '9'},
#   'id': '62053607',
#   'pos': [12.9742696, 77.5090727],
#   'type': 'node'},
#  {'created': {'changeset': '10281951',
#    'timestamp': '2012-01-03T14:47:01Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '6'},
#   'id': '62053614',
#   'pos': [12.9744393, 77.5091469],
#   'type': 'node'},
#  {'created': {'changeset': '44629818',
#    'timestamp': '2016-12-23T18:05:04Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '8'},
#   'highway': 'bus_stop',
#   'id': '62053620',
#   'local_ref': 'PAPAREDDY PALYA',
#   'name': 'Aladamara',
#   'name:kn': u'\u0c86\u0cb2\u0ca6\u0cae\u0cb0',
#   'pos': [12.9751302, 77.5094207],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:59Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053627',
#   'pos': [12.9762696, 77.509836],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:59Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '5'},
#   'id': '62053633',
#   'pos': [12.9772423, 77.5101303],
#   'type': 'node'},
#  {'created': {'changeset': '17344845',
#    'timestamp': '2013-08-14T13:17:07Z',
#    'uid': '1319316',
#    'user': 'Gururaja Upadhyaya',
#    'version': '6'},
#   'highway': 'bus_stop',
#   'id': '62053636',
#   'local_ref': 'NAGARABHAVI 2ND STAGE',
#   'name': 'Nagarabhavi BDA Complex',
#   'pos': [12.9795534, 77.5106479],
#   'type': 'node'},
#  {'created': {'changeset': '11321144',
#    'timestamp': '2012-04-16T11:52:47Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053640',
#   'pos': [12.9797574, 77.510698],
#   'type': 'node'},
#  {'created': {'changeset': '47864147',
#    'timestamp': '2017-04-17T09:40:54Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '13'},
#   'id': '62053645',
#   'pos': [12.960513, 77.5043695],
#   'type': 'node'},
#  {'created': {'changeset': '10568317',
#    'timestamp': '2012-02-02T15:13:24Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053663',
#   'pos': [12.9625239, 77.5049294],
#   'type': 'node'},
#  {'created': {'changeset': '10568317',
#    'timestamp': '2012-02-02T15:13:24Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053669',
#   'pos': [12.9632325, 77.505064],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '8'},
#   'id': '62053671',
#   'pos': [12.9634957, 77.5050838],
#   'type': 'node'},
#  {'created': {'changeset': '10568317',
#    'timestamp': '2012-02-02T15:13:24Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053673',
#   'pos': [12.9638808, 77.5050434],
#   'type': 'node'},
#  {'created': {'changeset': '10568317',
#    'timestamp': '2012-02-02T15:13:24Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053676',
#   'pos': [12.9641814, 77.5049758],
#   'type': 'node'},
#  {'created': {'changeset': '10568317',
#    'timestamp': '2012-02-02T15:13:24Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053681',
#   'pos': [12.9645541, 77.5048986],
#   'type': 'node'},
#  {'created': {'changeset': '10568317',
#    'timestamp': '2012-02-02T15:13:24Z',
#    'uid': '492742',
#    'user': 'docaneesh',
#    'version': '7'},
#   'id': '62053686',
#   'pos': [12.9653166, 77.5048795],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '7'},
#   'id': '62053690',
#   'pos': [12.9657605, 77.5049098],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '7'},
#   'id': '62053692',
#   'pos': [12.9661428, 77.5049837],
#   'type': 'node'},
#  {'created': {'changeset': '35643583',
#    'timestamp': '2015-11-29T10:54:06Z',
#    'uid': '161619',
#    'user': 'FvGordon',
#    'version': '7'},
#   'id': '62053697',
#   'pos': [12.9665523, 77.505087],
#   'type': 'node'},
#  {'created': {'changeset': '38444058',
#    'timestamp': '2016-04-10T07:18:57Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '7'},
#   'id': '62053706',
#   'pos': [12.9683611, 77.5059288],
#   'type': 'node'},
#  {'created': {'changeset': '31249451',
#    'timestamp': '2015-05-18T09:34:04Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '7'},
#   'id': '62053715',
#   'pos': [12.9696201, 77.5064186],
#   'type': 'node'},
#  {'created': {'changeset': '45335629',
#    'timestamp': '2017-01-20T19:42:21Z',
#    'uid': '136860',
#    'user': 'indigomc',
#    'version': '9'},
#   'highway': 'bus_stop',
#   'id': '62053719',
#   'name': 'Papareddy Palya',
#   'name:kn': u'\u0caa\u0cbe\u0caa\u0cb0\u0cc6\u0ca1\u0ccd\u0ca1\u0cbf \u0caa\u0cbe\u0cb3\u0ccd\u0caf',
#   'pos': [12.9720535, 77.5078547],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:42Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '6'},
#   'id': '62053730',
#   'pos': [12.97295, 77.5083885],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '8'},
#   'id': '62053741',
#   'pos': [12.974244, 77.5091991],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '7'},
#   'id': '62053742',
#   'pos': [12.9743061, 77.5092272],
#   'type': 'node'},
#  {'created': {'changeset': '607100',
#    'timestamp': '2008-10-28T07:31:42Z',
#    'uid': '63375',
#    'user': 'Divjo',
#    'version': '6'},
#   'id': '62053746',
#   'pos': [12.9745253, 77.5093212],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:34:59Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '9'},
#   'highway': 'bus_stop',
#   'id': '62053750',
#   'local_ref': 'PAPAREDDY PALYA',
#   'name': 'Aladamara',
#   'name:kn': u'\u0c86\u0cb2\u0ca6\u0cae\u0cb0',
#   'pos': [12.97534, 77.5096375],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '7'},
#   'id': '62053755',
#   'pos': [12.9764445, 77.5100108],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '7'},
#   'id': '62053757',
#   'pos': [12.977235, 77.5102219],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '7'},
#   'id': '62053760',
#   'pos': [12.9778045, 77.5103575],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '7'},
#   'id': '62053764',
#   'pos': [12.9785018, 77.5105086],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:13Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '8'},
#   'id': '62053768',
#   'pos': [12.9793248, 77.5106798],
#   'type': 'node'},
#  {'created': {'changeset': '36937831',
#    'timestamp': '2016-02-01T14:35:00Z',
#    'uid': '3080721',
#    'user': 'Swach Bharat',
#    'version': '8'},
#   'highway': 'bus_stop',
#   'id': '62053772',
#   'local_ref': 'NAGARABHAVI 2ND STAGE',
#   'name': 'Nagarabhavi BDA Complex',
#   'pos': [12.9796128, 77.5107487],
#   'type': 'node'},
#  {'created': {'changeset': '31249451',
#    'timestamp': '2015-05-18T09:34:05Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '4'},
#   'id': '62055100',
#   'pos': [12.9694689, 77.5068789],
#   'type': 'node'},
#  {'created': {'changeset': '31333606',
#    'timestamp': '2015-05-21T05:41:51Z',
#    'uid': '2901820',
#    'user': 'udaykanth',
#    'version': '4'},
#   'id': '62055107',
#   'pos': [12.9692389, 77.5075323],
#   'type': 'node'},
#  {'created': {'changeset': '31333606',
#    'timestamp': '2015-05-21T05:41:51Z',
#    'uid': '2901820',
#    'user': 'udaykanth',
#    'version': '3'},
#   'id': '62055112',
#   'pos': [12.9689601, 77.5086362],
#   'type': 'node'},
#  {'created': {'changeset': '17485778',
#    'timestamp': '2013-08-24T15:42:51Z',
#    'uid': '1319316',
#    'user': 'Gururaja Upadhyaya',
#    'version': '4'},
#   'highway': 'bus_stop',
#   'id': '62056921',
#   'name': 'Nagarabhavi 9th Block',
#   'pos': [12.9697447, 77.5091394],
#   'type': 'node'},
#  {'created': {'changeset': '13982558',
#    'timestamp': '2012-11-22T09:18:01Z',
#    'uid': '697874',
#    'user': 'Sandeep Nayak',
#    'version': '4'},
#   'id': '62056927',
#   'pos': [12.9694985, 77.509176],
#   'type': 'node'},
#  {'created': {'changeset': '13982558',
#    'timestamp': '2012-11-22T09:18:01Z',
#    'uid': '697874',
#    'user': 'Sandeep Nayak',
#    'version': '4'},
#   'id': '62056933',
#   'pos': [12.9669513, 77.5082722],
#   'type': 'node'},
#  {'created': {'changeset': '8149010',
#    'timestamp': '2011-05-15T08:44:29Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '62056939',
#   'pos': [12.9641619, 77.5107121],
#   'type': 'node'},
#  {'created': {'changeset': '8149010',
#    'timestamp': '2011-05-15T08:44:32Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '62056943',
#   'pos': [12.9635276, 77.5112201],
#   'type': 'node'},
#  {'created': {'changeset': '47864147',
#    'timestamp': '2017-04-17T09:40:54Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '62056949',
#   'pos': [12.9611772, 77.5107713],
#   'type': 'node'},
#  {'created': {'changeset': '47864147',
#    'timestamp': '2017-04-17T09:40:54Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '6'},
#   'highway': 'bus_stop',
#   'id': '62056953',
#   'local_ref': 'NGEF LAYOUT',
#   'name': 'NGF Layout',
#   'pos': [12.9610772, 77.5099853],
#   'type': 'node'},
#  {'created': {'changeset': '47864147',
#    'timestamp': '2017-04-17T09:40:54Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'highway': 'bus_stop',
#   'id': '62056965',
#   'name': 'Vinayaka Layout Bus Stop',
#   'pos': [12.9607472, 77.5074459],
#   'type': 'node'},
#  {'created': {'changeset': '47864147',
#    'timestamp': '2017-04-17T09:40:54Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '14'},
#   'highway': 'bus_stop',
#   'id': '62056980',
#   'local_ref': '80FEET Mallathahalli Road',
#   'name': 'ambedkar college stop',
#   'name:kn': u'\u0c85\u0c82\u0cac\u0cc7\u0ca1\u0ccd\u0c95\u0cb0\u0ccd \u0c95\u0cbe\u0cb2\u0cc7\u0c9c\u0cc1',
#   'operator': 'my college rote',
#   'pos': [12.9603832, 77.5049286],
#   'type': 'node'},
#  {'created': {'changeset': '10581764',
#    'timestamp': '2012-02-04T07:51:18Z',
#    'uid': '83660',
#    'user': 'Ashish Vijayaram',
#    'version': '9'},
#   'crossing': 'traffic_signals',
#   'highway': 'traffic_signals',
#   'id': '62067292',
#   'pos': [12.9614743, 77.5840912],
#   'type': 'node'},
#  {'created': {'changeset': '31248071',
#    'timestamp': '2015-05-18T08:45:39Z',
#    'uid': '2907853',
#    'user': 'masthanvali',
#    'version': '7'},
#   'id': '62067302',
#   'pos': [12.9615523, 77.5888332],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626012',
#   'pos': [12.9603633, 77.5043047],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626019',
#   'pos': [12.9599816, 77.50418],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626025',
#   'pos': [12.9592118, 77.5038997],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626029',
#   'pos': [12.9580853, 77.5034303],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '10'},
#   'highway': 'bus_stop',
#   'id': '66626034',
#   'name': 'Mallathalli Cross',
#   'name:kn': u'\u0cae\u0cb2\u0ccd\u0cb2\u0ca4\u0ccd\u0ca4\u0cb9\u0cb3\u0ccd\u0cb3\u0cbf',
#   'pos': [12.9571795, 77.5030561],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626035',
#   'pos': [12.9566777, 77.502871],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626037',
#   'pos': [12.9560007, 77.5025156],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626039',
#   'pos': [12.9554988, 77.5021884],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626040',
#   'pos': [12.9547643, 77.5016386],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626043',
#   'pos': [12.9541441, 77.5011028],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626044',
#   'pos': [12.9536373, 77.5006968],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '8'},
#   'id': '66626045',
#   'pos': [12.952779, 77.5001593],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'highway': 'bus_stop',
#   'id': '66626048',
#   'local_ref': 'JNANAJYOTHI NAGARA',
#   'name': 'University Quarters',
#   'pos': [12.9522993, 77.4998898],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626051',
#   'pos': [12.9517746, 77.4997107],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626053',
#   'pos': [12.95137, 77.4996041],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626055',
#   'pos': [12.9510165, 77.4994935],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626056',
#   'pos': [12.9506845, 77.4991676],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '9'},
#   'id': '66626058',
#   'pos': [12.9505159, 77.4988967],
#   'type': 'node'},
#  {'created': {'changeset': '47771616',
#    'timestamp': '2017-04-14T08:37:46Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
# ...
#   'pos': [12.8978836, 77.6022662],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:23:49Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '247996831',
#   'pos': [12.8977079, 77.6021547],
#   'type': 'node'},
#  {'created': {'changeset': '299432',
#    'timestamp': '2008-10-13T09:49:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '247999765',
#   'pos': [12.8946792, 77.6018714],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000226',
#   'pos': [12.8997075, 77.6009616],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000227',
#   'pos': [12.899239, 77.602395],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000228',
#   'pos': [12.8988123, 77.6036138],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000229',
#   'pos': [12.8981681, 77.6050729],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000230',
#   'pos': [12.8970888, 77.6048669],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000231',
#   'pos': [12.8964195, 77.6046867],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000232',
#   'pos': [12.8960179, 77.6056051],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000233',
#   'pos': [12.8946207, 77.6053304],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000234',
#   'pos': [12.893123, 77.6049012],
#   'type': 'node'},
#  {'created': {'changeset': '29722813',
#    'timestamp': '2015-03-25T09:35:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '248000235',
#   'pos': [12.8922156, 77.6046296],
#   'type': 'node'},
#  {'created': {'changeset': '29722813',
#    'timestamp': '2015-03-25T09:35:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '248000236',
#   'pos': [12.892281, 77.6043078],
#   'type': 'node'},
#  {'created': {'changeset': '29722813',
#    'timestamp': '2015-03-25T09:35:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '248000237',
#   'pos': [12.8920295, 77.6042232],
#   'type': 'node'},
#  {'created': {'changeset': '29722813',
#    'timestamp': '2015-03-25T09:35:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '248000239',
#   'pos': [12.892339, 77.6028905],
#   'type': 'node'},
#  {'created': {'changeset': '12970699',
#    'timestamp': '2012-09-03T17:41:13Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '2'},
#   'id': '248000240',
#   'pos': [12.8924727, 77.6019455],
#   'type': 'node'},
#  {'created': {'changeset': '12970699',
#    'timestamp': '2012-09-03T17:41:13Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '2'},
#   'id': '248000241',
#   'pos': [12.8925087, 77.6013541],
#   'type': 'node'},
#  {'created': {'changeset': '12970699',
#    'timestamp': '2012-09-03T17:41:13Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '2'},
#   'id': '248000242',
#   'pos': [12.8926436, 77.6006373],
#   'type': 'node'},
#  {'created': {'changeset': '12970699',
#    'timestamp': '2012-09-03T17:41:13Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '2'},
#   'id': '248000243',
#   'pos': [12.8927761, 77.5998966],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000244',
#   'pos': [12.8934075, 77.5991763],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000245',
#   'pos': [12.8951478, 77.5996055],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000246',
#   'pos': [12.8972227, 77.600172],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000247',
#   'pos': [12.8990382, 77.600747],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:47Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000248',
#   'pos': [12.8936334, 77.6015882],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:47Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000250',
#   'pos': [12.895131, 77.6019916],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:47Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000251',
#   'pos': [12.8952733, 77.601468],
#   'type': 'node'},
#  {'created': {'changeset': '141315',
#    'timestamp': '2008-02-17T11:54:47Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '1'},
#   'id': '248000252',
#   'pos': [12.8948549, 77.6012105],
#   'type': 'node'},
#  {'created': {'changeset': '40626060',
#    'timestamp': '2016-07-10T09:05:43Z',
#    'uid': '1765920',
#    'user': 'Nagesh_Blr',
#    'version': '12'},
#   'id': '248003858',
#   'pos': [12.9571515, 77.605872],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:10Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248003859',
#   'pos': [12.9557785, 77.6047477],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:10Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248003860',
#   'pos': [12.9565524, 77.6049357],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:11Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248003861',
#   'pos': [12.9583156, 77.6053271],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:11Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248003862',
#   'pos': [12.9576278, 77.6043334],
#   'type': 'node'},
#  {'created': {'changeset': '141220',
#    'timestamp': '2008-02-17T12:31:12Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248003863',
#   'pos': [12.9591327, 77.6039942],
#   'type': 'node'},
#  {'created': {'changeset': '18061403',
#    'timestamp': '2013-09-27T13:06:47Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '3'},
#   'id': '248003866',
#   'pos': [12.9550383, 77.60419],
#   'type': 'node'},
#  {'created': {'changeset': '553586',
#    'timestamp': '2008-10-24T07:10:43Z',
#    'uid': '35811',
#    'user': 'Praveen',
#    'version': '2'},
#   'id': '248003867',
#   'pos': [12.9553622, 77.603159],
#   'type': 'node'},
#  {'created': {'changeset': '828543',
#    'timestamp': '2009-03-18T14:29:15Z',
#    'uid': '35811',
#    'user': 'Praveen',
#    'version': '4'},
#   'id': '248007838',
#   'pos': [12.9126556, 77.5987763],
#   'type': 'node'},
#  {'created': {'changeset': '828543',
#    'timestamp': '2009-03-18T14:29:15Z',
#    'uid': '35811',
#    'user': 'Praveen',
#    'version': '4'},
#   'id': '248007839',
#   'pos': [12.9146853, 77.5986268],
#   'type': 'node'},
#  {'created': {'changeset': '828543',
#    'timestamp': '2009-03-18T14:27:56Z',
#    'uid': '35811',
#    'user': 'Praveen',
#    'version': '8'},
#   'id': '248007841',
#   'pos': [12.9077418, 77.59899],
#   'type': 'node'},
#  {'created': {'changeset': '18598983',
#    'timestamp': '2013-10-29T11:00:38Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '15'},
#   'id': '248007842',
#   'pos': [12.9127249, 77.5984783],
#   'type': 'node'},
#  {'building': 'residential',
#   'created': {'changeset': '29710823',
#    'timestamp': '2015-03-24T18:59:29Z',
#    'uid': '827808',
#    'user': 'yogi_ks',
#    'version': '2'},
#   'id': '248128247',
#   'name': 'Haydon Manor',
#   'pos': [12.9563028, 77.6047975],
#   'type': 'node'},
#  {'created': {'changeset': '13903678',
#    'timestamp': '2012-11-17T10:37:20Z',
#    'uid': '20181',
#    'user': 'santjohn',
#    'version': '8'},
#   'id': '248181104',
#   'pos': [12.937377, 77.5999716],
#   'type': 'node'},
#  {'created': {'changeset': '13903678',
#    'timestamp': '2012-11-17T10:37:20Z',
#    'uid': '20181',
#    'user': 'santjohn',
#    'version': '8'},
#   'id': '248181105',
#   'pos': [12.9378415, 77.5990845],
#   'type': 'node'},
#  {'created': {'changeset': '13903678',
#    'timestamp': '2012-11-17T10:37:20Z',
#    'uid': '20181',
#    'user': 'santjohn',
#    'version': '9'},
#   'id': '248181106',
#   'pos': [12.9387193, 77.5983155],
#   'type': 'node'},
#  {'created': {'changeset': '13902623',
#    'timestamp': '2012-11-17T08:34:17Z',
#    'uid': '20181',
#    'user': 'santjohn',
#    'version': '6'},
#   'id': '248181107',
#   'pos': [12.9392503, 77.598002],
#   'type': 'node'},
#  {'created': {'changeset': '13902623',
#    'timestamp': '2012-11-17T08:34:17Z',
#    'uid': '20181',
#    'user': 'santjohn',
#    'version': '9'},
#   'highway': 'traffic_signals',
#   'id': '248181109',
#   'pos': [12.9399643, 77.5976476],
#   'type': 'node'},
#  {'created': {'changeset': '88357',
#    'timestamp': '2008-12-03T19:27:51Z',
#    'uid': '74061',
#    'user': 'SrikanthLogic',
#    'version': '5'},
#   'id': '248181110',
#   'pos': [12.9433757, 77.5971896],
#   'type': 'node'},
#  {'created': {'changeset': '88357',
#    'timestamp': '2008-12-03T19:27:51Z',
#    'uid': '74061',
#    'user': 'SrikanthLogic',
#    'version': '5'},
#   'id': '248181111',
#   'pos': [12.9445767, 77.5970228],
#   'type': 'node'},
#  {'created': {'changeset': '9375116',
#    'timestamp': '2011-09-23T09:22:44Z',
#    'uid': '288815',
#    'user': 'Imad',
#    'version': '6'},
#   'id': '248181112',
#   'pos': [12.945115, 77.5967441],
#   'type': 'node'},
#  {'created': {'changeset': '9375116',
#    'timestamp': '2011-09-23T09:22:44Z',
#    'uid': '288815',
#    'user': 'Imad',
#    'version': '6'},
#   'id': '248181113',
#   'pos': [12.945443, 77.5963692],
#   'type': 'node'},
#  {'created': {'changeset': '10581764',
#    'timestamp': '2012-02-04T07:51:11Z',
#    'uid': '83660',
#    'user': 'Ashish Vijayaram',
#    'version': '8'},
#   'highway': 'traffic_signals',
#   'id': '248181114',
#   'pos': [12.9459312, 77.5955326],
#   'type': 'node'},
#  {'created': {'changeset': '9375116',
#    'timestamp': '2011-09-23T09:22:44Z',
#    'uid': '288815',
#    'user': 'Imad',
#    'version': '6'},
#   'id': '248181115',
#   'pos': [12.9465682, 77.594803],
#   'type': 'node'},
#  {'created': {'changeset': '9375116',
#    'timestamp': '2011-09-23T09:22:44Z',
#    'uid': '288815',
#    'user': 'Imad',
#    'version': '6'},
#   'id': '248181116',
#   'pos': [12.9470775, 77.5943458],
#   'type': 'node'},
#  {'created': {'changeset': '15186323',
#    'timestamp': '2013-02-27T15:39:59Z',
#    'uid': '606416',
#    'user': 'anttit',
#    'version': '6'},
#   'id': '248181122',
#   'pos': [12.9509714, 77.5918011],
#   'type': 'node'},
#  {'created': {'changeset': '15186323',
#    'timestamp': '2013-02-27T15:39:59Z',
#    'uid': '606416',
#    'user': 'anttit',
#    'version': '7'},
#   'id': '248181130',
#   'pos': [12.9511006, 77.5915942],
#   'type': 'node'},
#  {'created': {'changeset': '13145958',
#    'timestamp': '2012-09-17T16:40:55Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '2'},
#   'id': '248347275',
#   'pos': [12.8816006, 77.5968153],
#   'type': 'node'},
#  {'created': {'changeset': '2085544',
#    'timestamp': '2009-08-09T14:23:18Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '248455233',
#   'pos': [12.9617441, 77.5984669],
#   'type': 'node'},
#  {'created': {'changeset': '158001',
#    'timestamp': '2008-02-19T17:49:36Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248455235',
#   'pos': [12.9629146, 77.5997403],
#   'type': 'node'},
#  {'created': {'changeset': '33582967',
#    'timestamp': '2015-08-25T21:07:28Z',
#    'uid': '2748195',
#    'user': 'karitotp',
#    'version': '2'},
#   'id': '248455237',
#   'pos': [12.9635707, 77.6010568],
#   'type': 'node'},
#  {'created': {'changeset': '18061403',
#    'timestamp': '2013-09-27T13:06:46Z',
#    'uid': '634020',
#    'user': 'user_634020',
#    'version': '2'},
#   'id': '248455238',
#   'pos': [12.9595676, 77.6029922],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455241',
#   'pos': [12.9618607, 77.6014939],
#   'type': 'node'},
#  {'created': {'changeset': '158001',
#    'timestamp': '2008-02-19T17:49:44Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248455254',
#   'pos': [12.9628139, 77.6012778],
#   'type': 'node'},
#  {'created': {'changeset': '158001',
#    'timestamp': '2008-02-19T17:49:45Z',
#    'uid': '587',
#    'user': 'jace',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '248455255',
#   'pos': [12.9642717, 77.6009615],
#   'type': 'node'},
#  {'created': {'changeset': '247588',
#    'timestamp': '2008-12-07T04:00:13Z',
#    'uid': '74061',
#    'user': 'SrikanthLogic',
#    'version': '3'},
#   'id': '248455257',
#   'pos': [12.9653935, 77.6010377],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:40Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '248455258',
#   'pos': [12.9623497, 77.6002068],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:46Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '248455259',
#   'pos': [12.9613866, 77.5999712],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:43Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '248455260',
#   'pos': [12.9611482, 77.6010426],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:48Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455261',
#   'pos': [12.9621424, 77.6011755],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:45Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455262',
#   'pos': [12.9624715, 77.6000791],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:41Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455263',
#   'pos': [12.9626877, 77.5996462],
#   'type': 'node'},
#  {'created': {'changeset': '2086597',
#    'timestamp': '2009-08-09T15:52:59Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '248455265',
#   'pos': [12.9634268, 77.601004],
#   'type': 'node'},
#  {'created': {'changeset': '6778481',
#    'timestamp': '2010-12-27T14:49:43Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455275',
#   'pos': [12.9622204, 77.6012323],
#   'type': 'node'},
#  {'created': {'changeset': '16442157',
#    'timestamp': '2013-06-06T08:46:53Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455287',
#   'pos': [12.9631065, 77.6017439],
#   'type': 'node'},
#  {'created': {'changeset': '16442157',
#    'timestamp': '2013-06-06T08:46:53Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '248455288',
#   'pos': [12.963397, 77.6017642],
#   'type': 'node'},
#  ...]

# %%
import signal
import subprocess
##pro = subprocess.Popen('mongod', preexec_fn = os.setsid)

# %%
from pymongo import MongoClient

db_name = 'openstreetmap'

# Connect to Mongo DB
client = MongoClient('localhost:27017')
db = client[db_name]

# %%
# Build mongoimport command instead of using homebrew
collection = cal_data[:cal_data.find('.')]
json_file = cal_data + '.json'

mongoimport_cmd = 'mongoimport -h 127.0.0.1:27017 ' + \
                  '--db ' + db_name + \
                  ' --collection ' + collection + \
                  ' --file ' + json_file

# Before importing, drop collection if it is already running 
if collection in db.collection_names():
    print 'Dropping collection: ' + collection
    db[collection].drop()
    
# Execute the command
print 'Executing: ' + mongoimport_cmd
subprocess.call(mongoimport_cmd.split(),shell=True)
# Out:
# Executing: mongoimport -h 127.0.0.1:27017 --db openstreetmap --collection C:\Users\sampa\Desktop\Other\Udacity\Lesson 4\bangalore --file C:\Users\sampa\Desktop\Other\Udacity\Lesson 4\bangalore.osm.json
# 1

# %%
bangalore = db[collection]

# %%
import os
print 'The original OSM file is {} MB'.format(os.path.getsize(cal_data)/1.0e6) # convert from bytes to megabytes
print 'The JSON file is {} MB'.format(os.path.getsize(cal_data + ".json")/1.0e6) # convert from bytes to megabytes
# Out:
# The original OSM file is 668.159791 MB
# The JSON file is 788.602808 MB

# %%
bangalore.find().count()
# Out:
# 0

# %%
len(bangalore.distinct('created.user'))
# Out:
# 0
